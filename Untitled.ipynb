# %%
import os,sys
import re
reload(sys)  
sys.setdefaultencoding('utf8')
from selenium import webdriver


url = "https://www.google.com.tr/search?q={}".format("tcs")   

driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver")
driver.get(url)
content = driver.page_source

# %%
content
# Out:
# u'<!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en-IN"><head><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image" /><link href="/images/branding/product/ico/googleg_lodp.ico" rel="shortcut icon" /><meta content="origin" name="referrer" /><title>tcs - Google Search</title><script src="https://apis.google.com/_/scs/abc-static/_/js/k=gapi.gapi.en.29tAKSAI8cc.O/m=gapi_iframes,googleapis_client,plusone/rt=j/sv=1/d=1/ed=1/am=IA/rs=AHpOoo82FxkTgGRAoVn-fgFU3zdQ5QIqEw/cb=gapi.loaded_0" async=""></script><script nonce="6UmWwR7H25AE7Nb2m/ZzpA==">(function(){window.google={kEI:\'HJyOWqzGHcPG0gSw446wAg\',kEXPI:\'18168,1354277,1354690,1354915,1355219,1355457,1355528,1355675,1355762,1356040,1356179,1356435,1356690,1356779,1357033,1357219,1357402,1357808,3700251,3700439,3700521,4019511,4029815,4031109,4038214,4038394,4041776,4043492,4045096,4045293,4045839,4047140,4047454,4048347,4048980,4050750,4051887,4056126,4056682,4058016,4061666,4061980,4062724,4064468,4064796,4069829,4078588,4080760,4081038,4082230,4097153,4097194,4097470,4097922,4097929,4098721,4098728,4104202,4104658,4106647,4107684,4109293,4109316,4109489,4110086,4110931,4115624,4115697,4116279,4116731,4116926,4116928,4116935,4118798,4119032,4119034,4119036,4119160,4120660,4121174,4121805,4122511,4123641,4124850,4125837,4126203,4126754,4127086,4127306,4127366,4127372,4128586,4129520,4129559,4129633,4131247,4131370,4131834,4131853,4133290,4133797,4134716,4135025,4135084,4136073,4136092,4137461,4137597,4137646,4138986,4139458,4139720,4139722,4139728,4139730,4140104,4140168,4140232,4140236,4140277,4140287,4140292,4140323,4140333,4140338,4140786,4141160,4141161,4141174,4141175,4141298,4141445,4141601,4141706,4141916,4142071,4142328,4142334,4142558,4142560,4142574,4142834,4142849,4143278,4143677,4143817,4144442,4144544,4144704,4144803,4145088,4145463,4145467,4145485,4145489,4145772,4145836,4146094,4146146,4146149,4147436,4147900,4147943,4148060,4148267,4148279,4148304,4148326,4148328,4148330,4148332,4148571,4148608,4149017,4149027,4149271,4149304,4149337,4150005,4150017,4150184,4150361,4150429,4151268,4151296,4151351,4151369,4151389,4151701,4151918,4152044,4152049,4152195,4152212,4152219,4152298,4152592,4152593,4152727,4153062,4153222,4153366,4153367,4153499,4153545,4153548,4153567,4153616,4153953,4154185,4154203,4154213,4154376,4154497,4154506,4154747,4154752,4155118,4155149,4155167,4155249,4155384,4155444,4155569,4155611,4155658,4155684,4155769,4156008,4156086,4156093,4156096,10200083,10202524,15807764,41317155\',authuser:0,kscs:\'c9c918f0_HJyOWqzGHcPG0gSw446wAg\',u:\'c9c918f0\',kGL:\'IN\'};google.kHL=\'en-IN\';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var b;a&amp;&amp;(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||google.kEI};google.getLEI=function(a){for(var b=null;a&amp;&amp;(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b};google.https=function(){return"https:"==window.location.protocol};google.ml=function(){return null};google.wl=function(a,b){try{google.ml(Error(a),!1,b)}catch(d){}};google.time=function(){return(new Date).getTime()};google.log=function(a,b,d,c,g){if(a=google.logUrl(a,b,d,c,g)){b=new Image;var e=google.lc,f=google.li;e[f]=b;b.onerror=b.onload=b.onabort=function(){delete e[f]};google.vel&amp;&amp;google.vel.lu&amp;&amp;google.vel.lu(a);b.src=a;google.li=f+1}};google.logUrl=function(a,b,d,c,g){var e="",f=google.ls||"";d||-1!=b.search("&amp;ei=")||(e="&amp;ei="+google.getEI(c),-1==b.search("&amp;lei=")&amp;&amp;(c=google.getLEI(c))&amp;&amp;(e+="&amp;lei="+c));c="";!d&amp;&amp;google.cshid&amp;&amp;-1==b.search("&amp;cshid=")&amp;&amp;(c="&amp;cshid="+google.cshid);a=d||"/"+(g||"gen_204")+"?atyp=i&amp;ct="+a+"&amp;cad="+b+e+f+"&amp;zx="+google.time()+c;/^http:/i.test(a)&amp;&amp;google.https()&amp;&amp;(google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a};}).call(this);(f ...

# %%
import spacy
parser = spacy.load('en')
example=u"That this House notes the announcement of 300 redundancies at the Nestlé manufacturing factories in York, Fawdon, Halifax and Girvan and that production of the Blue Riband bar will be transferred to Poland; acknowledges in the first three months of 2017 Nestlé achieved £21 billion in sales, a 0.4 per cent increase over the same period in 2016; further notes 156 of these job losses will be in York, a city that in the last six months has seen 2,000 job losses announced and has become the most inequitable city outside of the South East, and a further 110 jobs from Fawdon, Newcastle; recognises the losses come within a month of triggering Article 50, and as negotiations with the EU on the UK leaving the EU and the UK's future with the EU are commencing; further recognises the cost of importing products, including sugar, cocoa and production machinery, has risen due to the weakness of the pound and the uncertainty over the UK's future relationship with the single market and customs union; and calls on the Government to intervene and work with hon. Members, trades unions GMB and Unite and the company to avert these job losses now and prevent further job losses across Nestle"

# %%
print("1")
print(example)
parsedEx = parser(content)
print("2")

print("-------------- entities only ---------------")
# if you just want the entities and nothing else, you can do access the parsed examples "ents" property like this:
ents = list(parsedEx.ents)
tags={}
for entity in ents:
    #print(entity.label, entity.label_, ' '.join(t.orth_ for t in entity))
    term=' '.join(t.orth_ for t in entity)
    if ' '.join(term) not in tags:
        tags[term]=[(entity.label, entity.label_)]
    else:
        tags[term].append((entity.label, entity.label_))
print(tags)

# %%
tags
# Out:
# {u'91;case': [(394L, u'CARDINAL')],
#  u'Error("F`"+c);a': [(381L, u'ORG')],
#  u'6px': [(393L, u'ORDINAL')],
#  u'\xa0 - \xa0': [(381L, u'ORG')],
#  u'16px;color:#777;text': [(394L, u'CARDINAL')],
#  u'relative}.gb_N': [(378L, u'PERSON')],
#  u'duf3 - 46;authority:0;card_id:;entry_point:0;feature_id:;header:0;open:0;suggestions:;suggestions_subtypes:;suggestions_types:;surface:0;type:46"><style': [(394L,
#    u'CARDINAL')],
#  u'Jan 17 ,': [(388L, u'DATE')],
#  u'Error("p");Hd++;return': [(378L, u'PERSON')],
#  u'null,2,null': [(388L, u'DATE')],
#  u'ifZQhH2fNhVw-_UwgkgYBDrI': [(382L, u'GPE')],
#  u'rect(50px 470px': [(378L, u'PERSON')],
#  u'left;height:13px;margin - right:3px;margin - top:4px;width:13px}#nav': [(378L,
#    u'PERSON')],
#  u'0 - 9.]+)/,h=(g': [(394L, u'CARDINAL')],
#  u'top;width:1.5em}.gb_bd': [(378L, u'PERSON')],
#  u'Ci': [(378L, u'PERSON')],
#  u'Window]"==d)return"object";if("[object Array]"==d||"number"==typeof a.length&amp;&amp;"undefined"!=typeof a.splice&amp;&amp;"undefined"!=typeof': [(381L,
#    u'ORG')],
#  u'name="referrer': [(381L, u'ORG')],
#  u'# 999;bottom:30px;padding:10px 0;position': [(391L, u'MONEY')],
#  u'clnk&amp;gl': [(378L, u'PERSON')],
#  u'd;d': [(381L, u'ORG')],
#  u'd;e': [(378L, u'PERSON')],
#  u'\\u003Cb\\u003EAllow\\u003C / b\\u003E': [(381L, u'ORG')],
#  u'd;a': [(379L, u'NORP')],
#  u'9px': [(393L, u'ORDINAL')],
#  u'a+Math.random()*(c': [(381L, u'ORG')],
#  u'e.screenX||0,this.screenY': [(381L, u'ORG')],
#  u'C;a': [(394L, u'CARDINAL')],
#  u'middle}#hdtbSum': [(381L, u'ORG')],
#  u'Gi': [(378L, u'PERSON')],
#  u'c;Oo(a': [(381L, u'ORG')],
#  u'id="eobs_8': [(386L, u'WORK_OF_ART')],
#  u'null!==a&amp;&amp;c in a?a[c]:void 0};De': [(448L, u'LAW')],
#  u'g.action||"",m': [(378L, u'PERSON')],
#  u'C;a.w[c]||(a': [(378L, u'PERSON')],
#  u'middle}.gb_S': [(389L, u'TIME')],
#  u'0===a.style[e]&amp;&amp;(e=(_.eb?"Webkit":_.db?"Moz":_.C?"ms":_.ab?"O"': [(394L,
#    u'CARDINAL')],
#  u'e=0;e&lt;d;e++)c.push(a[e]);return': [(378L, u'PERSON')],
#  u'alt="Day': [(379L, u'NORP')],
#  u'week</a></li><li': [(394L, u'CARDINAL')],
#  u'a.b.forEach(function(a': [(382L, u'GPE')],
#  u'0.218s}.s2fp': [(394L, u'CARDINAL')],
#  u'Ao(a.offsetWidth': [(381L, u'ORG')],
#  u'e){return Wd(this': [(378L, u'PERSON')],
#  u'2341px;background': [(394L, u'CARDINAL')],
#  u'f=_.p(a)?a.split(""):a': [(378L, u'PERSON')],
#  u'220ms': [(378L, u'PERSON')],
#  u'Array.prototype.slice.call(arguments)))},this);return this.o[a]=c': [(378L,
#    u'PERSON')],
#  u'Zn': [(378L, u'PERSON')],
#  u'Zh': [(378L, u'PERSON')],
#  u'8px}.gb_7c': [(388L, u'DATE')],
#  u'8px}#center_col': [(394L, u'CARDINAL')],
#  u'function(){window.console&amp;&amp;window.console.log&amp;&amp;window.console.log("Log': [(382L,
#    u'GPE')],
#  u'null;return': [(394L, u'CARDINAL')],
#  u'subform_ctrl{margin': [(382L, u'GPE')],
#  u'more\\u003C / a\\u003E","hl":"en -': [(381L, u'ORG')],
#  u'ebebeb;margin': [(391L, u'MONEY')],
#  u'0 2px': [(390L, u'PERCENT')],
#  u'd6d6d6;box': [(391L, u'MONEY')],
#  u'e=[],f=0;f&lt;d.length;f++)e[f]=d[f].gb();a.b[c]=d;_.V(a': [(381L, u'ORG')],
#  u'https://www.glassdoor.co.in / Overview / Working - at - Reliance - InfoTech': [(381L,
#    u'ORG')],
#  u'# ebebeb;margin - bottom:14px;margin': [(391L, u'MONEY')],
#  u'pp));_.x("gbar.abh",(0,_.v)(pp.tc , pp,0));_.x("gbar.adh",(0,_.v)(pp.tc': [(389L,
#    u'TIME')],
#  u'nowrap}.gb_T': [(378L, u'PERSON')],
#  u'Reliance Infotech': [(381L, u'ORG')],
#  u'h3{font - size:18px}.e{margin:2px': [(378L, u'PERSON')],
#  u'class="card': [(381L, u'ORG')],
#  u'Array.prototype.concat.apply([],arguments)};_.U': [(378L, u'PERSON')],
#  u'La': [(378L, u'PERSON')],
#  u'c=0,d;d': [(381L, u'ORG')],
#  u'Li': [(378L, u'PERSON')],
#  u'7px}#pocs.sft{background': [(394L, u'CARDINAL')],
#  u'Ic(g);e=!1!==h.call(l': [(381L, u'ORG')],
#  u'ji(a.description);return}if(window.navigator.plugins["Shockwave Flash': [(381L,
#    u'ORG')],
#  u"gt:'S',i": [(378L, u'PERSON')],
#  u'ICxnu - SGsqE': [(381L, u'ORG')],
#  u'a.exec(_.Sa))?a[0].replace(/_/g,"."):"10"):_.kb?(a=/Android\\s+([^\\);]+)(\\)|;)/,(a': [(382L,
#    u'GPE')],
#  u'true,"host":"google.com.tr","isbh":44,"mara"': [(382L, u'GPE')],
#  u'bold;height:25px;line - height:19px;padding': [(378L, u'PERSON')],
#  u'T.length?a': [(382L, u'GPE')],
#  u'0==a.lastIndexOf(c,0)};_.Lc': [(9191306739292312949L, u'FAC')],
#  u'try{c': [(378L, u'PERSON')],
#  u'\n tg.prototype.clear=function(){this.b=this.w=null;this.o=0};tg.prototype.Ec=function(){Eg(this);return': [(9191306739292312949L,
#    u'FAC')],
#  u'Microsoft.gradient(startColorstr=#160000ff': [(378L, u'PERSON')],
#  u'50px': [(393L, u'ORDINAL')],
#  u'Gn(a);_.pf(d,"");_.qe(function(){_.pf(d': [(382L, u'GPE')],
#  u'0;background': [(394L, u'CARDINAL')],
#  u'190:case 191:case': [(385L, u'EVENT')],
#  u'c){if(_.p(a))return': [(378L, u'PERSON')],
#  u'Reliance Mobile': [(378L, u'PERSON')],
#  u'Uttar': [(381L, u'ORG')],
#  u'gbqfbw{display': [(391L, u'MONEY')],
#  u'class="hdtb': [(381L, u'ORG')],
#  u'a{color:#777}#hdtb': [(388L, u'DATE')],
#  u'0 1px 2px rgba(0,0,0,0.3)}.gb_6c.gb_7c{padding:0}.gb_7c': [(388L, u'DATE')],
#  u'No.1 Job Portal': [(381L, u'ORG')],
#  u'title="Google': [(379L, u'NORP')],
#  u'Reliance Communications , Ltd.': [(381L, u'ORG')],
#  u'hover,.hdtbItm.hdtbSel': [(394L, u'CARDINAL')],
#  u'c={};c.items=(0,_.ya)(a.o': [(381L, u'ORG')],
#  u'Mobile': [(382L, u'GPE')],
#  u'0;"><a': [(384L, u'PRODUCT')],
#  u'c;})();</script></div></div></div></div></div></div><div': [(378L,
#    u'PERSON')],
#  u'c=0,d = this.b.length;c&lt;d;c++){var': [(381L, u'ORG')],
#  u'S&amp;&amp;_.M(this': [(378L, u'PERSON')],
#  u'a.w));return': [(378L, u'PERSON')],
#  u'd,!0,e': [(381L, u'ORG')],
#  u'kj(a': [(384L, u'PRODUCT')],
#  u'Eo(a.b,"width",!0);(0,window.isNaN)(h)&amp;&amp;(h': [(381L, u'ORG')],
#  u'https://www.glassdoor.co.in / Overview / Working - at - Reliance - InfoTech - EI_IE760510.11,28.htm%2B%26cd%3D1%26hl%3Den%26ct%3Dclnk%26gl%3Din&amp;ved=0ahUKEwiXuf65ibnZAhUJUZQKHfTkD_0QIAgpMAA"': [(381L,
#    u'ORG')],
#  u'# fff}.vk_bk.vk_ard,.vk_bk.vk_aru{background': [(391L, u'MONEY')],
#  u'India': [(382L, u'GPE')],
#  u'color:#ff4444;border:0;box': [(382L, u'GPE')],
#  u'0!==a.style[e]&amp;&amp;(d': [(394L, u'CARDINAL')],
#  u'rgba(0,0,0,0.2);box': [(385L, u'EVENT')],
#  u'style="clear : both;position : relative;zoom:1"><div id="bcenter"><div class="col "': [(386L,
#    u'WORK_OF_ART')],
#  u'c.next': [(381L, u'ORG')],
#  u'a;this.o': [(378L, u'PERSON')],
#  u'M[c]=a};_.k': [(382L, u'GPE')],
#  u'class="ctbs': [(379L, u'NORP')],
#  u'block;height:100%;width:100%}.s2er{}.s2fp{}.s2fp - h{}.s2ml{}.s2ra{}.s2tb{}.s2tb - h{}.spch{}.spchc{}.spch{background:#fff;height:100%;left:0;opacity:0;overflow': [(381L,
#    u'ORG')],
#  u'   <': [(382L, u'GPE')],
#  u'd){if(null==this)throw': [(388L, u'DATE')],
#  u'h.split&amp;&amp;_.Dc(h.split(/\\s+/),c)&amp;&amp;(g[e++]=a)}g.length=e;return': [(388L,
#    u'DATE')],
#  u'e.next==d': [(381L, u'ORG')],
#  u'Ja;_.Ia="bbh': [(381L, u'ORG')],
#  u'0}}.gb_Pb': [(394L, u'CARDINAL')],
#  u'Yo();c&amp;&amp;_.Zf(c,"gb_9a",!a': [(381L, u'ORG')],
#  u'absolute;top:-6px;width:100%}.gb_Vc': [(382L, u'GPE')],
#  u'15px}.gb_ac': [(394L, u'CARDINAL')],
#  u'10px;"': [(378L, u'PERSON')],
#  u'a),0==d.o&amp;&amp;(d.src': [(388L, u'DATE')],
#  u'0;width:20px"></span>3</a></td><td><a': [(394L, u'CARDINAL')],
#  u'\n Eo': [(9191306739292312949L, u'FAC')],
#  u'\\"Ok': [(381L, u'ORG')],
#  u'5px;transition': [(394L, u'CARDINAL')],
#  u'H+"://"+_.J(_.F(a,2)),"og/_/ss","k="+_.J(_.F(a,13))];this': [(382L,
#    u'GPE')],
#  u'd[e]&amp;&amp;d[e]!==Object.prototype[e]?d': [(378L, u'PERSON')],
#  u'this[e],g': [(378L, u'PERSON')],
#  u'ebebeb}#resultStats{line': [(391L, u'MONEY')],
#  u'a.dataset.ampc?c=1:a.dataset.ampd&amp;&amp;(c=2),0!=c&amp;&amp;(b': [(378L,
#    u'PERSON')],
#  u'43px': [(394L, u'CARDINAL')],
#  u'xjs/_/js / k': [(381L, u'ORG')],
#  u'class\\x3d\\x22hdtb': [(381L, u'ORG')],
#  u'37:e': [(394L, u'CARDINAL')],
#  u'jobs.html': [(378L, u'PERSON')],
#  u'Search': [(381L, u'ORG')],
#  u'Verbatim</a></li></ul><span': [(382L, u'GPE')],
#  u'Yc,$c;_.Ac': [(379L, u'NORP')],
#  u'class="appbar': [(382L, u'GPE')],
#  u'right:12px}.sbibod{background - color:#fff;height:44px;vertical': [(384L,
#    u'PRODUCT')],
#  u'scale(1)}.s2tb': [(382L, u'GPE')],
#  u'Jb.vc);0&lt;B&amp;&amp;N==r': [(382L, u'GPE')],
#  u'13.09': [(394L, u'CARDINAL')],
#  u'150ms': [(382L, u'GPE')],
#  u'Learn more</a></div': [(378L, u'PERSON')],
#  u'foot{width:632px}.gbh{top:24px}#gbar{margin - left:8px;height:20px}#guser{margin - right:8px;padding - bottom:5px': [(381L,
#    u'ORG')],
#  u'c[l];B=0&lt;f?r': [(378L, u'PERSON')],
#  u'rgba(0,0,0,.12)}.mn - hd - txt{display': [(378L, u'PERSON')],
#  u'2px 2px': [(388L, u'DATE')],
#  u'nEjf2CObCkc;$x 0': [(382L, u'GPE')],
#  u'\n\n': [(388L, u'DATE')],
#  u'absolute;right:0;top:44px;z - index:-1}.gb_cb': [(381L, u'ORG')],
#  u'a.b.style.width;a.b.style.width="";return': [(378L, u'PERSON')],
#  u'Lucky","lml":"Learn more","oskt":"Input': [(378L, u'PERSON')],
#  u'Similar</a></li></ol></div></div></div><span': [(382L, u'GPE')],
#  u'jsaction="tnv.scf': [(386L, u'WORK_OF_ART')],
#  u'function(e){throw': [(393L, u'ORDINAL')],
#  u'reliance%20infotech': [(379L, u'NORP')],
#  u'c=_.wi();return': [(378L, u'PERSON')],
#  u'Qa': [(378L, u'PERSON')],
#  u'Oa="gbar."+Ka[Na];null==_.t(Oa': [(383L, u'LOC')],
#  u'a)||this.o&amp;&amp;!!_.Dc(jj': [(382L, u'GPE')],
#  u'2d6200}.kpgrb{background': [(391L, u'MONEY')],
#  u'Oc&amp;&amp;(h.push(r),q+=B)}c': [(382L, u'GPE')],
#  u'visited,#prs': [(378L, u'PERSON')],
#  u'a,#hdtb - more - mn': [(388L, u'DATE')],
#  u'c){_.Kj().log(a': [(378L, u'PERSON')],
#  u'href="https://www.glassdoor.com / Reviews / Reliance - InfoTech - Reviews - E760510.htm': [(381L,
#    u'ORG')],
#  u'0;min': [(394L, u'CARDINAL')],
#  u'normal;width:328px': [(378L, u'PERSON')],
#  u'd,_.Cc(e)?!!e.capture:!!e': [(382L, u'GPE')],
#  u'this.gbar': [(382L, u'GPE')],
#  u'ebebeb;left:28px;width:264px}.gb_ma': [(391L, u'MONEY')],
#  u'Helvetica': [(381L, u'ORG')],
#  u'Pj(this),Qj(this),Rj(this,!1,a))}};_.Oj.prototype.ga': [(379L, u'NORP')],
#  u'd){if(a.qa)throw': [(388L, u'DATE')],
#  u"e};google.dljp('/xjs/_/js / k\\x3dxjs.s.en.e4sLKce4KZE.O / m\\x3dsx": [(381L,
#    u'ORG')],
#  u'192:case 222:return!1}if(_.C&amp;&amp;e&amp;&amp;c==a)return!1;switch(a){case': [(382L,
#    u'GPE')],
#  u'span\\x3e\\x3c': [(378L, u'PERSON')],
#  u'Pvt Ltd': [(381L, u'ORG')],
#  u'MochiKit': [(381L, u'ORG')],
#  u'd=_.Kj();d=_.$o(d': [(381L, u'ORG')],
#  u'Searches': [(378L, u'PERSON')],
#  u'1};_.ic': [(394L, u'CARDINAL')],
#  u'a.replace(/%25([0': [(382L, u'GPE')],
#  u'hover,.gb_ld': [(382L, u'GPE')],
#  u'10px}.sbsb_d{background:#eee}.sbsb_e{height:1px;background': [(394L,
#    u'CARDINAL')],
#  u'2&gt;=arguments.length?Array.prototype.slice.call(a': [(394L, u'CARDINAL')],
#  u'0}.gb_ea': [(388L, u'DATE')],
#  u'c});a.addEventListener?a.addEventListener(b': [(382L, u'GPE')],
#  u'c=["MSXML2.XMLHTTP.6.0","MSXML2.XMLHTTP.3.0","MSXML2.XMLHTTP","Microsoft': [(382L,
#    u'GPE')],
#  u'c=[],d=[],e': [(381L, u'ORG')],
#  u'range\\x3c': [(378L, u'PERSON')],
#  u'String(a).replace(/\\-([a - z])/g': [(382L, u'GPE')],
#  u'iygzmo4EtCLI - eEjGhTK0s34': [(378L, u'PERSON')],
#  u'Reliance</em >': [(389L, u'TIME')],
#  u'hveid="104': [(384L, u'PRODUCT')],
#  u'a);a': [(378L, u'PERSON')],
#  u'position:-428px': [(378L, u'PERSON')],
#  u'e){_.Cc(a)?(this.top-=a.top': [(378L, u'PERSON')],
#  u'Software Development &': [(381L, u'ORG')],
#  u'# center_col,#cnt': [(391L, u'MONEY')],
#  u'16px 30px': [(388L, u'DATE')],
#  u'scale(1.4,1.4)}50%{-webkit': [(378L, u'PERSON')],
#  u'Wi;d': [(378L, u'PERSON')],
#  u'relative}._pxg': [(378L, u'PERSON')],
#  u'absolute;z - index:2}.gb_Sb ::-': [(381L, u'ORG')],
#  u'src=" / xjs/_/js / k': [(381L, u'ORG')],
#  u'function(){Jo': [(382L, u'GPE')],
#  u'topabar.vasqHeight{margin-top:-44px': [(391L, u'MONEY')],
#  u'search.</span': [(382L, u'GPE')],
#  u'0s': [(394L, u'CARDINAL')],
#  u'rtid="ifZQhH2fNhVw': [(381L, u'ORG')],
#  u'company/11463823/&amp;ved=0ahUKEwiXuf65ibnZAhUJUZQKHfTkD_0QFghHMAM"': [(378L,
#    u'PERSON')],
#  u'style="white - space :': [(386L, u'WORK_OF_ART')],
#  u'class="iygzmo4EtCLI - uhagcrfPmuU': [(386L, u'WORK_OF_ART')],
#  u'c.parentNode;return': [(378L, u'PERSON')],
#  u'c){_.nn[a]=c;c': [(382L, u'GPE')],
#  u'role="combobox': [(386L, u'WORK_OF_ART')],
#  u'x(a){n.removeEventListener("click",x);a.stopPropagation&amp;&amp;a.stopPropagation()}function y(a){++q;a': [(378L,
#    u'PERSON')],
#  u'Vc.hasOwnProperty(e)?a.setAttribute(Vc[e],c):_.Kc(e,"aria-")||_.Kc(e,"data-")?a.setAttribute(e': [(394L,
#    u'CARDINAL')],
#  u'absolute;padding:0 20px': [(394L, u'CARDINAL')],
#  u'Bo(this.o));this.rf&amp;&amp;(this.o&amp;&amp;(To(this),_.Q(this.o,"gb_T"),this.b&amp;&amp;_.Q(this.b,"gb_T"),_.Do()||(this.w= \n So(Ro))),this.cb(),window.setTimeout((0,_.v)(this.cb': [(9191306739292312949L,
#    u'FAC')],
#  u'0;width:20px"></span>1</td><td><a': [(391L, u'MONEY')],
#  u'calc(100 %': [(390L, u'PERCENT')],
#  u'M.h=0,M.o': [(378L, u'PERSON')],
#  u'e,!1):c&amp;&amp;c.attachEvent?c.attachEvent("on"+d': [(382L, u'GPE')],
#  u'12px}._Mhk{margin - top:0px}._YQd{background': [(388L, u'DATE')],
#  u'middle}.gb_fb': [(381L, u'ORG')],
#  u'middle;color:#4285f4}.sbico': [(394L, u'CARDINAL')],
#  u'0 1px': [(388L, u'DATE')],
#  u'for="cdr_max"': [(383L, u'LOC')],
#  u'G);e+=a': [(378L, u'PERSON')],
#  u'B.w': [(386L, u'WORK_OF_ART')],
#  u'hover,.gb_Ff': [(394L, u'CARDINAL')],
#  u'id="hdtb - s': [(384L, u'PRODUCT')],
#  u'C||(a': [(394L, u'CARDINAL')],
#  u'c6c6c6;color:#222;}.ab_button': [(391L, u'MONEY')],
#  u'null)}}if(!a)throw': [(388L, u'DATE')],
#  u'tick",zi(this': [(394L, u'CARDINAL')],
#  u'Bj);_.Dj': [(379L, u'NORP')],
#  u'210px 16px 194px);left:-164px;top:22px}.gb_N': [(381L, u'ORG')],
#  u'A)for(;a&amp;&amp;a': [(381L, u'ORG')],
#  u'0 1px 2px rgba(0,0,0,0.3);-webkit - box': [(388L, u'DATE')],
#  u'3px': [(393L, u'ORDINAL')],
#  u'gapi.loaded_0': [(378L, u'PERSON')],
#  u'186:case': [(394L, u'CARDINAL')],
#  u'a,#tadsb': [(378L, u'PERSON')],
#  u'd=(0,_.w)().toString();_.V(c,1,d)}for(;1E3&lt;=this.b.length;)this.b.shift(),++this': [(382L,
#    u'GPE')],
#  u'2px;position': [(394L, u'CARDINAL')],
#  u'class="gsfi': [(381L, u'ORG')],
#  u'style="top:0;left:0;right:0;width:100 %': [(390L, u'PERCENT')],
#  u'href="https://www.glassdoor.co.in / Overview / Working - at - Reliance - InfoTech - EI_IE760510.11,28.htm': [(381L,
#    u'ORG')],
#  u'X&amp;ved=0ahUKEwiXuf65ibnZAhUJUZQKHfTkD_0QpwUIHg"': [(378L, u'PERSON')],
#  u'B){if(ln(f': [(382L, u'GPE')],
#  u'g&amp;&amp;(f[h]=c.call(d': [(382L, u'GPE')],
#  u'Va': [(378L, u'PERSON')],
#  u'Vi': [(378L, u'PERSON')],
#  u'function(d){a.call(c': [(378L, u'PERSON')],
#  u'style>#gb{font - size:13px}#gb{position': [(381L, u'ORG')],
#  u'radius:2px;bottom:0;font - size:11px;font': [(385L, u'EVENT')],
#  u'f){return Wd(this': [(378L, u'PERSON')],
#  u'class="spell_orig': [(381L, u'ORG')],
#  u'class\\x3d\\x22q': [(378L, u'PERSON')],
#  u'height:18px}.srg': [(378L, u'PERSON')],
#  u'\n } \n c&amp;&amp;(c.className+=n);s&amp;&amp;(s.className+=n);}catch(e': [(381L,
#    u'ORG')],
#  u'hdtbMenus,.tmhi': [(391L, u'MONEY')],
#  u'304:case': [(394L, u'CARDINAL')],
#  u'0;transform': [(394L, u'CARDINAL')],
#  u'a.b.offsetWidth': [(394L, u'CARDINAL')],
#  u'function(){_.Gc(this.o': [(382L, u'GPE')],
#  u'class="hdtbna': [(381L, u'ORG')],
#  u'null,0],[1],[0,1,["lg"],1,["lat"]],[["","","","","","","","","","","","","","","","","","","","def","","","","","","","","",""],[""]],null': [(388L,
#    u'DATE')],
#  u'zd;_.xd="closure_listenable_"+(1E6*Math.random()|0);_.yd': [(378L,
#    u'PERSON')],
#  u'9==a.nodeType?a': [(394L, u'CARDINAL')],
#  u'0px 1px 2px rgba(0,0,0,0.3)}body.vasq': [(381L, u'ORG')],
#  u'rgba(0,0,0,0.12);line - height:16px;margin - left:10px;padding:7px': [(381L,
#    u'ORG')],
#  u'f){(f||this.b).ra(a': [(378L, u'PERSON')],
#  u'Global Services Pvt Ltd': [(381L, u'ORG')],
#  u'# fff!important}sentinel{}</style><script': [(391L, u'MONEY')],
#  u'a.clientY+c': [(382L, u'GPE')],
#  u'9.5S7.01': [(394L, u'CARDINAL')],
#  u'c.left):(a': [(382L, u'GPE')],
#  u'24 24"><path': [(394L, u'CARDINAL')],
#  u'Experienced': [(381L, u'ORG')],
#  u'ActiveXObject(a):new': [(381L, u'ORG')],
#  u'# fsr{display': [(391L, u'MONEY')],
#  u'https://www.glassdoor.co.in / Overview /': [(381L, u'ORG')],
#  u'size:64px': [(381L, u'ORG')],
#  u'Hc': [(382L, u'GPE')],
#  u'D(c.w': [(378L, u'PERSON')],
#  u'a.match(_.re)[1]||null;!a&amp;&amp;_.m.self&amp;&amp;_.m.self.location&amp;&amp;(a=_.m.self.location.protocol': [(382L,
#    u'GPE')],
#  u'Instant': [(381L, u'ORG')],
#  u'em{color:#6a6a6a}.s': [(378L, u'PERSON')],
#  u'String(_.m.location.href);return': [(382L, u'GPE')],
#  u'586px': [(378L, u'PERSON')],
#  u'0px': [(393L, u'ORDINAL')],
#  u'class="b': [(381L, u'ORG')],
#  u'X&amp;ved=0ahUKEwiXuf65ibnZAhUJUZQKHfTkD_0QHwg5MAI"': [(379L, u'NORP')],
#  u't_nYWbCdeK4;$x 0': [(393L, u'ORDINAL')],
#  u'Wj[c]);a': [(378L, u'PERSON')],
#  u'0;text': [(394L, u'CARDINAL')],
#  u'rgba(0,0,0,0.1);color:#444;}.ab_button{background': [(382L, u'GPE')],
#  u'c){google.lq.push([[a],b': [(394L, u'CARDINAL')],
#  u'Keep</span></a></li><li': [(381L, u'ORG')],
#  u'style="height :': [(386L, u'WORK_OF_ART')],
#  u'e=_.Wf(c);d': [(381L, u'ORG')],
#  u'class="gb_qb"></div></div><div': [(381L, u'ORG')],
#  u'navend"><span': [(384L, u'PRODUCT')],
#  u'5,"><span': [(394L, u'CARDINAL')],
#  u'href=': [(382L, u'GPE')],
#  u'vh(f': [(381L, u'ORG')],
#  u'span{opacity:.55;-webkit': [(378L, u'PERSON')],
#  u'eee}.vk_gbr{border': [(391L, u'MONEY')],
#  u'weight:500}.gb_bd': [(378L, u'PERSON')],
#  u'Kf;_.Ve': [(378L, u'PERSON')],
#  u'Z': [(378L, u'PERSON')],
#  u'id="gbsfw': [(382L, u'GPE')],
#  u'd;this.o=(0,_.v)(this': [(381L, u'ORG')],
#  u'2147483647&lt;Number(c)?-1:_.m.setTimeout(a': [(394L, u'CARDINAL')],
#  u'a}-1&lt;e?(a': [(378L, u'PERSON')],
#  u'serif}.gb_bd': [(378L, u'PERSON')],
#  u'd){a=_.F(a': [(383L, u'LOC')],
#  u'radius:8px;border - radius:8px;font': [(381L, u'ORG')],
#  u'value="Google Search': [(378L, u'PERSON')],
#  u'txt\\x22\\x3eAny': [(379L, u'NORP')],
#  u'20px': [(393L, u'ORDINAL')],
#  u'image","srch":"Google': [(381L, u'ORG')],
#  u'reviews</div></div><span': [(378L, u'PERSON')],
#  u'cdr_go\\x22': [(388L, u'DATE')],
#  u'gradient(top,#4387fd,#4683ea);filter': [(382L, u'GPE')],
#  u'nW': [(381L, u'ORG')],
#  u'/span>1': [(381L, u'ORG')],
#  u'c)e': [(382L, u'GPE')],
#  u'200ms': [(382L, u'GPE')],
#  u'c+"Top");a=_.ef(a': [(381L, u'ORG')],
#  u'e={},h': [(382L, u'GPE')],
#  u'title="Search': [(386L, u'WORK_OF_ART')],
#  u'width:1100px;z - index:103}div.sfbg': [(378L, u'PERSON')],
#  u'c};_.u': [(378L, u'PERSON')],
#  u'window.jsl||{};window.jsl.dh = window.jsl.dh||function(i': [(391L,
#    u'MONEY')],
#  u'c.substring(0': [(382L, u'GPE')],
#  u'd)){d': [(378L, u'PERSON')],
#  u'c){_.Gc(c': [(381L, u'ORG')],
#  u'gif;base64,R0lGODlhEAAQAKIHAPzu7PfT0Oh5cfGtqONbUuBLQeBKP////yH5BAEAAAcALAAAAAAQABAAAANKeLrcfkAI8NowZtQFCCbUJmCYsAWFAQBGEVSjyhqmc2HBnDUdGQQkEOOGA5I0CkCKxMQUQjEnAMU0GUkuZTPgaRaWTEK0Sa5tGgkAOw': [(378L,
#    u'PERSON')],
#  u'relative}.gb_da': [(378L, u'PERSON')],
#  u'A),a': [(381L, u'ORG')],
#  u'safesearchlock_transparent.png': [(378L, u'PERSON')],
#  u'Today': [(388L, u'DATE')],
#  u'tbpi{margin': [(391L, u'MONEY')],
#  u'right}._HR{margin - left:166px;line': [(378L, u'PERSON')],
#  u'Number(a);return 0==c&amp;&amp;_.yh(a)?window': [(378L, u'PERSON')],
#  u'200:case': [(394L, u'CARDINAL')],
#  u'0': [(394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL')],
#  u'GSM Service': [(381L, u'ORG')],
#  u'this.b);this.b': [(382L, u'GPE')],
#  u'0&lt;a.length?String(a[0]):c': [(394L, u'CARDINAL')],
#  u'class="_Fmb ab_button "': [(378L, u'PERSON')],
#  u'function(){_.z.call(this);this.b': [(378L, u'PERSON')],
#  u'0;overflow': [(394L, u'CARDINAL')],
#  u'class\\x3d\\x22cdr_cont': [(382L, u'GPE')],
#  u'A&amp;&amp;!_.Dc(jj': [(378L, u'PERSON')],
#  u'f));a.h': [(388L, u'DATE')],
#  u'null,30000,null': [(388L, u'DATE')],
#  u'style="white': [(382L, u'GPE')],
#  u'ved="0ahUKEwiXuf65ibnZAhUJUZQKHfTkD_0Q7B0IXTAI"><span': [(394L,
#    u'CARDINAL')],
#  u'g);g=!g;r': [(381L, u'ORG')],
#  u'd,1);break;case 40:e': [(381L, u'ORG')],
#  u'e){c&amp;&amp;c.qb&amp;&amp;(c': [(378L, u'PERSON')],
#  u'style="clear': [(378L, u'PERSON')],
#  u'e){if(3==d&amp;&amp;c.o&amp;&amp;!c': [(378L, u'PERSON')],
#  u'0;width:20px"></span>4</a></td><td><a': [(394L, u'CARDINAL')],
#  u'f;f': [(378L, u'PERSON')],
#  u'd===_.Ib?a.w[c]=[]:d}d': [(378L, u'PERSON')],
#  u'Md': [(378L, u'PERSON')],
#  u'f[g],g': [(385L, u'EVENT')],
#  u'Mc': [(378L, u'PERSON')],
#  u'Mi': [(382L, u'GPE')],
#  u'000;border': [(391L, u'MONEY')],
#  u'href="http://www.relianceglobal.com/': [(378L, u'PERSON')],
#  u'd):_.M(a': [(382L, u'GPE')],
#  u'f){this.b': [(382L, u'GPE')],
#  u'g);else{c=_.Id(c': [(378L, u'PERSON')],
#  u'c)||(a.currentStyle?a.currentStyle[c]:null)||a.style&amp;&amp;a.style[c]};_.gf': [(388L,
#    u'DATE')],
#  u'q,"",null);b.path?(M.s': [(388L, u'DATE')],
#  u'24px 16px}.vk_c': [(388L, u'DATE')],
#  u'span,#botstuff': [(378L, u'PERSON')],
#  u'd){2==c?a.w.call(a.context': [(378L, u'PERSON')],
#  u'color:#212121}._vm{font - size:11px': [(384L, u'PRODUCT')],
#  u'X&amp;ved=0ahUKEwiXuf65ibnZAhUJUZQKHfTkD_0Q_AUIDSgE"': [(378L, u'PERSON')],
#  u'c=[];a': [(382L, u'GPE')],
#  u'0.34 seconds': [(389L, u'TIME')],
#  u'4d90fe;box': [(391L, u'MONEY')],
#  u'e.screenY||0);this.button': [(381L, u'ORG')],
#  u'inline}.hdtbSel,.hdtbSel': [(378L, u'PERSON')],
#  u'9.5 14z"/></svg></span></button><div': [(384L, u'PRODUCT')],
#  u'xf(a);else': [(381L, u'ORG')],
#  u'0 3.09-.59 4.23 -': [(390L, u'PERCENT')],
#  u'B[a.getId': [(378L, u'PERSON')],
#  u'a.ab_button': [(378L, u'PERSON')],
#  u'188:case': [(381L, u'ORG')],
#  u'a]:[g.join(":"),d': [(381L, u'ORG')],
#  u'2f5bb7}a.kpbb': [(391L, u'MONEY')],
#  u'href="//support.google.com': [(381L, u'ORG')],
#  u'a/133fc21e88.png': [(382L, u'GPE')],
#  u'c){if(c&lt;a': [(386L, u'WORK_OF_ART')],
#  u'0}.gb_Hc': [(394L, u'CARDINAL')],
#  u'd.o[a]}};_.Ca': [(379L, u'NORP')],
#  u'e&amp;&amp;c.call(void': [(381L, u'ORG')],
#  u'Reliance InfoTech Reviews': [(381L, u'ORG')],
#  u'a{color:#dd4b39}#ab_ctls{float': [(382L, u'GPE')],
#  u'1': [(394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL')],
#  u'# fff;color:#fff}.gb_Pb.gb_ea': [(391L, u'MONEY')],
#  u'Languages</span></a><a class="_VJq': [(378L, u'PERSON')],
#  u'window.document,"gbqfb': [(378L, u'PERSON')],
#  u'no(mo(_.yh,_.rh(ko': [(388L, u'DATE')],
#  u'Math.floor(this.top);this.width': [(394L, u'CARDINAL')],
#  u'Turn': [(378L, u'PERSON')],
#  u'g=0;g&lt;a.length;++g)if(!(d&amp;&amp;a[g].type!=e||f&amp;&amp;a[g].capture!=c))return!0;return!1})};var Dd': [(381L,
#    u'ORG')],
#  u'0)};sg': [(394L, u'CARDINAL')],
#  u'16px;position': [(394L, u'CARDINAL')],
#  u'g=0,h;h': [(378L, u'PERSON')],
#  u'a.b)return': [(382L, u'GPE')],
#  u'1);}.lst{border:0;margin - top:5px;margin - bottom:0}.lst': [(388L,
#    u'DATE')],
#  u'Rd': [(378L, u'PERSON')],
#  u'0;width:20px"></span>8</a></td><td><a': [(394L, u'CARDINAL')],
#  u'999;border': [(391L, u'MONEY')],
#  u'Rc': [(378L, u'PERSON')],
#  u'India</span': [(378L, u'PERSON')],
#  u'g){if(!(_.C||_.bb||_.eb&amp;&amp;_.vb("525")))return!0;if(_.hb&amp;&amp;f)return': [(378L,
#    u'PERSON')],
#  u'href="https://www.indiamart.com / company/11463823/': [(381L, u'ORG')],
#  u'hidden;z': [(382L, u'GPE')],
#  u'c[g],d': [(382L, u'GPE')],
#  u'a};_.k': [(378L, u'PERSON')],
#  u'a];(0,_.wa)(e': [(382L, u'GPE')],
#  u'Noida': [(382L, u'GPE')],
#  u'null,\\"86400000\\",0,[\\"86400000\\",\\"604800000\\",2.0]\\n]\\n': [(382L,
#    u'GPE')],
#  u'0 0;position': [(394L, u'CARDINAL')],
#  u'Rating': [(382L, u'GPE')],
#  u'a.href': [(378L, u'PERSON')],
#  u'a.firstChild;a;){if(c(a)&amp;&amp;(d.push(a),e)||_.tn(a': [(382L, u'GPE')],
#  u'B?(c+=a': [(378L, u'PERSON')],
#  u'0;min - width:54px;padding:0': [(384L, u'PRODUCT')],
#  u'ved="0ahUKEwiXuf65ibnZAhUJUZQKHfTkD_0Q7B0ITTAE"><span': [(394L,
#    u'CARDINAL')],
#  u'Math.ceil(this.top);this.width': [(394L, u'CARDINAL')],
#  u'class="ivYSwloPrD3I - uhagcrfPmuU': [(381L, u'ORG')],
#  u'static}.srp': [(379L, u'NORP')],
#  u'Na("ready",l': [(378L, u'PERSON')],
#  u'0!=a.children?a.children:(0,_.xa)(a.childNodes': [(394L, u'CARDINAL')],
#  u'msb&gt;.hdtb': [(388L, u'DATE')],
#  u'4px}.gsst_a': [(394L, u'CARDINAL')],
#  u'd)&amp;&amp;g==this.ba)return;f.o&amp;&amp;(this.dispatchEvent(new': [(378L,
#    u'PERSON')],
#  u'g))break;a.b': [(378L, u'PERSON')],
#  u'class="f"': [(382L, u'GPE')],
#  u'a.gb_ja,#gb': [(388L, u'DATE')],
#  u'Infotech Software Solution': [(381L, u'ORG')],
#  u'K||this.o.o||this.o.start();c&amp;&amp;c()},this);this.ca(d': [(382L,
#    u'GPE')],
#  u'target=\\"_blank\\"\\u003EDetails\\u003C / a\\u003E","rm":"Speak now"},"tl":{"key":"AIzaSyC_9Rt88UMjzgg5pIVArnfuIVkJx4zCdTY"},"vs":{},"d":{},"csi":{"dlm"': [(394L,
#    u'CARDINAL')],
#  u'Job': [(384L, u'PRODUCT')],
#  u'rgba(0,0,0,.3);border:5px': [(381L, u'ORG')],
#  u'Xj(c),Wj[c.ka]=c': [(382L, u'GPE')],
#  u'd;a.prototype.constructor': [(381L, u'ORG')],
#  u'About 5,40,000': [(394L, u'CARDINAL')],
#  u'role="button': [(386L, u'WORK_OF_ART')],
#  u'd7d7d7;box': [(391L, u'MONEY')],
#  u'Vi;f': [(378L, u'PERSON')],
#  u'173:return': [(394L, u'CARDINAL')],
#  u'a.gb_Fa.gb_Fa{cursor:default;text-decoration:none}.gb_Fa{border:1px': [(382L,
#    u'GPE')],
#  u'Microsoft.gradient(startColorstr=#4387fd': [(382L, u'GPE')],
#  u'inherit}.gb_Wc': [(381L, u'ORG')],
#  u'm;h': [(378L, u'PERSON')],
#  u'Navi Mumbai': [(378L, u'PERSON')],
#  u'# dd4b39}.kprb': [(391L, u'MONEY')],
#  u'Reliance Infocomm</em': [(381L, u'ORG')],
#  u'medium}h4.r{font': [(378L, u'PERSON')],
#  u'K).b);var': [(394L, u'CARDINAL')],
#  u'function(){this.b={};this.o={}};_.na(_.Ba);_.Da': [(393L, u'ORDINAL')],
#  u'Z)};_.y(_.ij': [(381L, u'ORG')],
#  u'true},"TG8rFw":{"sd":"1"},"Iz7bbg":{},"XiiKIQ":{},"GDHetg":{},"71W8GA":{},"7Fjppg":{},"I7Pl5g":{},"RLN7pw":{},"BmJv2w":{},"aQRXjA":{},"JC6ZFg":{},"NZvGvg":{},"bnhGTQ":{},"ZI': [(382L,
#    u'GPE')],
#  u'f&amp;&amp;c.call(d': [(9191306739292312949L, u'FAC')],
#  u'first': [(393L, u'ORDINAL')],
#  u'one': [(394L, u'CARDINAL')],
#  u'ma(d),c;a:{for(c=0;c&lt;a.h.length;c++)if(S(a.h[c],d)){c=!0;break': [(379L,
#    u'NORP')],
#  u'Start': [(378L, u'PERSON')],
#  u'h=0,e': [(378L, u'PERSON')],
#  u'default;font - size:22px;font': [(378L, u'PERSON')],
#  u'height:40px;text': [(394L, u'CARDINAL')],
#  u'hidden}.f,.f': [(378L, u'PERSON')],
#  u'1s': [(394L, u'CARDINAL')],
#  u'c+1),Re(a': [(382L, u'GPE')],
#  u'e){return a.set(c.key,c.caption,d,e)};Yn.prototype.Cb=function(){};Yn.prototype.N=function(){return': [(378L,
#    u'PERSON')],
#  u'tsf{width:1109px}#topstuff': [(391L, u'MONEY')],
#  u'auto;right:6.5px}.gb_sb{outline': [(379L, u'NORP')],
#  u'a.ab_button:active,a.ab_button.selected,a.ab_button.selected:hover{color:#333}.ab_button:focus{outline:none}.ab_button.selected:focus{border-color:#ccc}.ab_button:hover&gt;span.ab_icon{opacity:0.9}#ab_opt_icon{background-position:-42px -259px;margin - top:-2px;border - radius:50%;display': [(378L,
#    u'PERSON')],
#  u'c){google.timers[a]||google.startTick(a);c': [(378L, u'PERSON')],
#  u'2': [(394L, u'CARDINAL'), (394L, u'CARDINAL'), (394L, u'CARDINAL')],
#  u'# aaa;box - shadow:1px': [(391L, u'MONEY')],
#  u'0;width:20px"></span>5</a></td><td><a': [(394L, u'CARDINAL')],
#  u'Glassdoor.co.in</a></h3><div': [(378L, u'PERSON')],
#  u'more\\u003C / a\\u003E","pe":"Voice': [(381L, u'ORG')],
#  u'10': [(394L, u'CARDINAL')],
#  u'focus{opacity:.85}.gb_X': [(381L, u'ORG')],
#  u'14': [(394L, u'CARDINAL')],
#  u'X&amp;ved=0ahUKEwiXuf65ibnZAhUJUZQKHfTkD_0Q1QIIdSgE"': [(378L, u'PERSON')],
#  u'null,0,null': [(382L, u'GPE')],
#  u'A,!1,this);this.b=_.af(this.o)},Bn': [(378L, u'PERSON')],
#  u'c;_.P.J.ne.call(a': [(378L, u'PERSON')],
#  u'cdr_mm cdr_min\\x22': [(378L, u'PERSON')],
#  u'none}#top_nav': [(394L, u'CARDINAL')],
#  u'.gb_le,.gb_kb.gb_zg': [(388L, u'DATE')],
#  u'a?(b=/[?&amp;]ved=([^&amp;]+)/.exec(a.href))?b[1]:"":"",a.dataset.ved= \n': [(381L,
#    u'ORG')],
#  u'navigator&amp;&amp;/iPhone|iPad|iPod/.test(navigator.userAgent),Q': [(379L,
#    u'NORP')],
#  u'c){this.nb': [(378L, u'PERSON')],
#  u'8px}.gsfs{font:16px': [(381L, u'ORG')],
#  u'right:5px}.gb_Bf': [(388L, u'DATE')],
#  u'Openings': [(9191306739292312949L, u'FAC')],
#  u'Dg': [(378L, u'PERSON')],
#  u'a?a.documentMode': [(378L, u'PERSON')],
#  u'rgba(255,255,255,.9);}._v1h{color:#9e9e9e;cursor': [(379L, u'NORP')],
#  u'class="_dMq': [(381L, u'ORG')],
#  u'rgba(0,0,0,.16)}.gb_bd .gb_cd{color:#222;margin - bottom:8px}.gb_bd': [(378L,
#    u'PERSON')],
#  u'B)+"px";_.R(a.b,"gb_W");c&amp;&amp;Oo(a.w': [(378L, u'PERSON')],
#  u'QEnjPPAAAAAElFTkSuQmCC)}._ayg{background': [(378L, u'PERSON')],
#  u'if(a.firstChild&amp;&amp;3==a.firstChild.nodeType){for(;a.lastChild!=a.firstChild;)a.removeChild(a.lastChild);a.firstChild.data': [(381L,
#    u'ORG')],
#  u'this.left-=a.left):(this.top-=a': [(378L, u'PERSON')],
#  u'n={key:"ok",caption:"OK"},ao={key:"cancel",caption:"Cancel"},bo={key:"yes",caption:"Yes"},co={key:"no",caption:"No"},eo={key:"save",caption:"Save"},fo={key:"continue",caption:"Continue': [(391L,
#    u'MONEY')],
#  u'c=0;c&lt;Ej.length;c++)Fj[Ej[c]]=!0}return!!Fj[a]},Hj': [(394L,
#    u'CARDINAL')],
#  u'd){c&lt;a': [(378L, u'PERSON')],
#  u'function(a){a.kc=!0;a.listener': [(381L, u'ORG')],
#  u'pp));_.x("gbar.cls",(0,_.v)(pp.lg': [(378L, u'PERSON')],
#  u'reliance+infotech&amp;um=1&amp;ie': [(381L, u'ORG')],
#  u'd[f.className]);h&amp;&amp;c.w.push(h)}return c }': [(378L, u'PERSON')],
#  u'link,.w,#prs': [(378L, u'PERSON')],
#  u'1;"': [(394L, u'CARDINAL')],
#  u'a.gl{color:#1a0dab}#center_col{clear:both}#res{border:0;margin:0;padding:0 16px;}#extrares{padding:0': [(381L,
#    u'ORG')],
#  u'Wd': [(378L, u'PERSON')],
#  u'gbqf{margin': [(391L, u'MONEY')],
#  u'r.listener': [(384L, u'PRODUCT')],
#  u'Wi': [(378L, u'PERSON')],
#  u'none}.kno - ecr': [(378L, u'PERSON')],
#  u'results\\x3c': [(382L, u'GPE')],
#  u'Window&amp;&amp;_.m': [(382L, u'GPE')],
#  u'class="r - ilAE40Z8BBI4"><div class="kN9UDnqLeMg__explore -': [(386L,
#    u'WORK_OF_ART')],
#  u'fuser{display': [(391L, u'MONEY')],
#  u'Reviews': [(379L, u'NORP')],
#  u'September 8 , 2006': [(388L, u'DATE')],
#  u'rgba(0,0,0,.54)}.gb_Xc': [(379L, u'NORP')],
#  u'c){c=(0,window.parseInt)(c': [(381L, u'ORG')],
#  u'size}.gb_R.gb_Hg{float': [(382L, u'GPE')],
#  u'f.parentNode)d.push(f);a': [(382L, u'GPE')],
#  u'function(a){hj(a': [(378L, u'PERSON')],
#  u'f);return': [(382L, u'GPE')],
#  u'Yi=[3,5],Zi': [(378L, u'PERSON')],
#  u'TypeError("First': [(393L, u'ORDINAL')],
#  u'B.offsetWidth - Fo(a': [(378L, u'PERSON')],
#  u'e=_.Ba': [(388L, u'DATE')],
#  u'K||this.o.o||this.o.start': [(378L, u'PERSON')],
#  u'none}.gb_6b{padding:118px 0;text - align': [(378L, u'PERSON')],
#  u'a)?(this.w': [(381L, u'ORG')],
#  u'13px;background:#ffffff}.gb_8c.gb_7c': [(394L, u'CARDINAL')],
#  u'a[e],e': [(382L, u'GPE')],
#  u'1.5s': [(392L, u'QUANTITY')],
#  u'# a0a0a0;box': [(391L, u'MONEY')],
#  u'Rel Track</a></div></div></div><div': [(381L, u'ORG')],
#  u'2px 4px': [(388L, u'DATE')],
#  u'3': [(394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL')],
#  u'U();_.k.zd': [(378L, u'PERSON')],
#  u'0;width:20px"></span>2</a></td><td><a': [(394L, u'CARDINAL')],
#  u'none}.obsmo': [(382L, u'GPE')],
#  u'www.relianceglobal.com/%2B%26cd%3D3%26hl%3Den%26ct%3Dclnk%26gl%3Din&amp;ved=0ahUKEwiXuf65ibnZAhUJUZQKHfTkD_0QIAg4MAI"': [(379L,
#    u'NORP')],
#  u'Flights</a><a': [(382L, u'GPE')],
#  u'this.b': [(382L, u'GPE')],
#  u'f))&amp;&amp;_.Qd(c': [(378L, u'PERSON')],
#  u'0 1px 2px 0': [(388L, u'DATE')],
#  u'location","uul_text":"Noida': [(382L, u'GPE')],
#  u'class="_bMq': [(379L, u'NORP')],
#  u'absolute;z - index:103;line': [(381L, u'ORG')],
#  u'this.o': [(382L, u'GPE')],
#  u'# fff}.gb_Ob': [(394L, u'CARDINAL')],
#  u'div><style>.fmulti{}.loc{}.swml - src{}.swml - upd{}.swml - loc{}._dQc{bottom:0;left:0;position': [(378L,
#    u'PERSON')],
#  u'role="menuitem': [(386L, u'WORK_OF_ART')],
#  u'gb__nb{0%{-webkit': [(378L, u'PERSON')],
#  u'Cached</a></li></ol></div></div></div><span class="st"': [(381L, u'ORG')],
#  u'420px 32px 388px)}}.gb_N .gb_dc,.gb_N .gbii,.gb_N': [(385L, u'EVENT')],
#  u'Ed(this.jb': [(382L, u'GPE')],
#  u'right;z - index:986;-webkit': [(378L, u'PERSON')],
#  u'c6c6c6;color:#222;}.ksb': [(391L, u'MONEY')],
#  u'a))});_.x("gbar.elr",Vo);_.Xo': [(379L, u'NORP')],
#  u'c.length),f=0;0==d&amp;&amp;f&lt;e;f++){var': [(378L, u'PERSON')],
#  u'f={};for(d': [(382L, u'GPE')],
#  u'c.substring(0,d));a': [(394L, u'CARDINAL')],
#  u'Learn': [(378L, u'PERSON')],
#  u'0;position': [(394L, u'CARDINAL')],
#  u'_ .tf': [(389L, u'TIME')],
#  u'class="cdr_ttl"': [(382L, u'GPE')],
#  u'iygzmo4EtCLI - ZgH0LU9o8RU': [(379L, u'NORP')],
#  u'0,f?f': [(394L, u'CARDINAL')],
#  u'scrollbar{height:15px;width:15px}.gb_Jf': [(381L, u'ORG')],
#  u'N()&amp;&amp;a.oa': [(381L, u'ORG')],
#  u'function(a){ro();return': [(378L, u'PERSON')],
#  u'focus{opacity:1}@media': [(382L, u'GPE')],
#  u'Ubu': [(378L, u'PERSON')],
#  u'c);this.o?this.o.next': [(381L, u'ORG')],
#  u'7.01': [(394L, u'CARDINAL')],
#  u'r.listener;if(B.Gc==c&amp;&amp;B.Ci==e){f?f.ra(a': [(378L, u'PERSON')],
#  u'c)},h': [(378L, u'PERSON')],
#  u'block;line - height:24px;margin:0}.gb_sb.gb_tb': [(389L, u'TIME')],
#  u'A||this.o)a=_.F(a,3)?"https://jmt17.google.com': [(381L, u'ORG')],
#  u'class="cdr_cls " jsaction="r .': [(386L, u'WORK_OF_ART')],
#  u'Ic': [(378L, u'PERSON')],
#  u'g,!!e': [(381L, u'ORG')],
#  u'resultStats{line': [(391L, u'MONEY')],
#  u'function(){a=!0}});_.m.addEventListener("test",_.ma': [(394L, u'CARDINAL')],
#  u'c[e]);f&amp;&amp;(d': [(382L, u'GPE')],
#  u'c.onabort': [(382L, u'GPE')],
#  u'Jobs': [(378L, u'PERSON')],
#  u'B=!0;ld(function(){a': [(378L, u'PERSON')],
#  u'country</div><span': [(382L, u'GPE')],
#  u'c(e[g]);a.b[d]=f}c': [(388L, u'DATE')],
#  u'none!important}.gb_N': [(379L, u'NORP')],
#  u'RELIANCE': [(381L, u'ORG')],
#  u'Error("N");}return': [(384L, u'PRODUCT')],
#  u'c){_.Mj().log(a': [(381L, u'ORG')],
#  u'12px;text': [(394L, u'CARDINAL')],
#  u'd),_.Fc(a)),this.o+=a.length))},a));a': [(381L, u'ORG')],
#  u'aria - label="Page': [(389L, u'TIME')],
#  u'11.11 16': [(384L, u'PRODUCT')],
#  u'c[d-3]^c[d-8]^c[d-14]^c[d-16],c[d]=(a&lt;&lt;1|a&gt;&gt;&gt;31)&amp;4294967295;a': [(382L,
#    u'GPE')],
#  u'href\\x3d\\x22/search?q\\x3dreliance+infotech\\x26amp;source\\x3dlnt\\x26amp;tbs\\x3dli:1\\x26amp;sa\\x3dX\\x26amp;ved\\x3d0ahUKEwiXuf65ibnZAhUJUZQKHfTkD_0QpwUIHg\\x22\\x3eVerbatim\\x3c / a\\x3e\\x3c / li\\x3e\\x3c / ul\\x3e\\x3cspan': [(381L,
#    u'ORG')],
#  u'c):Array.prototype.slice.call(a': [(378L, u'PERSON')],
#  u'hover,.gl': [(378L, u'PERSON')],
#  u'right:15px}.gb_T.gb_Lg': [(378L, u'PERSON')],
#  u'Fo(a.b));c': [(378L, u'PERSON')],
#  u'Find Latest': [(378L, u'PERSON')],
#  u'Module_:syd': [(391L, u'MONEY')],
#  u'Module_:syj': [(381L, u'ORG')],
#  u'Module_:syk': [(382L, u'GPE')],
#  u'Module_:syh': [(378L, u'PERSON')],
#  u'Module_:syi': [(391L, u'MONEY')],
#  u'wiki</div></div><span': [(382L, u'GPE')],
#  u'Module_:syl': [(391L, u'MONEY')],
#  u'Module_:sym': [(391L, u'MONEY')],
#  u'0==e&amp;&amp;(e=-1);return{className': [(394L, u'CARDINAL')],
#  u'scale(1.1,1.1)}to{-webkit': [(378L, u'PERSON')],
#  u'function(){return(_.A("Chrome")||_.A("CriOS"))&amp;&amp;!_.A("Edge")};_.Wa': [(382L,
#    u'GPE')],
#  u'fff}.gb_N': [(391L, u'MONEY')],
#  u'null;a.cd': [(379L, u'NORP')],
#  u'0.218s}.s2wfp': [(394L, u'CARDINAL')],
#  u'Jobs - Naukri.com</a></h3><div': [(378L, u'PERSON')],
#  u'g.call(f||a': [(378L, u'PERSON')],
#  u'up.nap': [(378L, u'PERSON')],
#  u'c,!1):a.attachEvent&amp;&amp;a.detachEvent("on"+b': [(378L, u'PERSON')],
#  u'd;do{g=!0;h=[];for(l': [(378L, u'PERSON')],
#  u'd}return': [(384L, u'PRODUCT')],
#  u'0.218s': [(394L, u'CARDINAL')],
#  u'class="gb_O': [(381L, u'ORG')],
#  u'se(/Android\\s+([0 - 9.]+)/))?a': [(391L, u'MONEY')],
#  u'style="width:0"><div id="center_col"><div id="taw"><style>.spell{font - size:18px}.spell_orig{font - size:15px}#mss p{margin:0;padding - top:5px}</style><div></div><div': [(386L,
#    u'WORK_OF_ART')],
#  u'Module_:sy6': [(378L, u'PERSON')],
#  u'Module_:sy7': [(378L, u'PERSON')],
#  u'a,0,-1,null)},vj': [(382L, u'GPE')],
#  u'Module_:sy5': [(378L, u'PERSON')],
#  u'Module_:sy9': [(378L, u'PERSON')],
#  u'_': [(381L, u'ORG'),
#   (381L, u'ORG'),
#   (388L, u'DATE'),
#   (388L, u'DATE'),
#   (381L, u'ORG'),
#   (388L, u'DATE'),
#   (393L, u'ORDINAL'),
#   (393L, u'ORDINAL')],
#  u'gd.get();d.set(a': [(378L, u'PERSON')],
#  u'Hyderabad': [(382L, u'GPE')],
#  u'bold;left:0;line': [(382L, u'GPE')],
#  u'function(){c.postMessage(d': [(378L, u'PERSON')],
#  u'function(a){f.push(a)});a': [(382L, u'GPE')],
#  u'0.0s}.ksb': [(393L, u'ORDINAL')],
#  u'Ni': [(378L, u'PERSON')],
#  u'Nc': [(382L, u'GPE')],
#  u'tabindex\\x3d\\x221\\x22 jsaction\\x3d\\x22focus': [(381L, u'ORG')],
#  u'hover,.flt': [(379L, u'NORP')],
#  u'nowrap}#fsett{background:#fff;border:1px': [(378L, u'PERSON')],
#  u'd);_.Jc(a': [(394L, u'CARDINAL')],
#  u'Cd?a': [(378L, u'PERSON')],
#  u'29691d}.kpgb': [(391L, u'MONEY')],
#  u'e,!1):a.detachEvent&amp;&amp;a.detachEvent("on"+c': [(379L, u'NORP')],
#  u'0;width:20px"></span>6</a></td><td><a': [(394L, u'CARDINAL')],
#  u'absolute;top:36px;min - width:328px;max - width:650px;right:0;-webkit - border - radius:2px;border - radius:2px': [(378L,
#    u'PERSON')],
#  u'class="cdr_mml': [(382L, u'GPE')],
#  u'this.fa));this': [(382L, u'GPE')],
#  u'class="r - igNrKMsxaJ6c"><div class="cdr_sep"></div><span class="q': [(386L,
#    u'WORK_OF_ART')],
#  u'X&amp;ved=0ahUKEwiXuf65ibnZAhUJUZQKHfTkD_0Q1QIIcigB"': [(378L, u'PERSON')],
#  u'USA': [(382L, u'GPE')],
#  u'b};I.prototype.l': [(388L, u'DATE')],
#  u'c){return Object.prototype.hasOwnProperty.call(a': [(378L, u'PERSON')],
#  u'g=0;g&lt;c.length;g++)_.Pd(a': [(378L, u'PERSON')],
#  u'K);_.Se(this': [(382L, u'GPE')],
#  u'9cb0d8;cursor': [(391L, u'MONEY')],
#  u'relative;z - index:99}#subform_ctrl': [(381L, u'ORG')],
#  u'Reliance Infotech Pvt Ltd': [(381L, u'ORG')],
#  u'Uttar Pradesh"},"elog":{},"foot":{"pf"': [(388L, u'DATE')],
#  u'0};vn': [(394L, u'CARDINAL')],
#  u'5': [(394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL')],
#  u'transparent;top:0;width:100%;height:22px;position': [(394L, u'CARDINAL')],
#  u'g)){b': [(378L, u'PERSON')],
#  u'snapshot.asp%3FprivcapId%3D7372777&amp;ved=0ahUKEwiXuf65ibnZAhUJUZQKHfTkD_0QFghpMAk"': [(378L,
#    u'PERSON')],
#  u'c.prototype[d].apply(a,e': [(388L, u'DATE')],
#  u'RobotoDraft': [(381L, u'ORG')],
#  u'href="https://hangouts.google.com/': [(386L, u'WORK_OF_ART')],
#  u'B?a.w[c+a': [(378L, u'PERSON')],
#  u'class="gb_kb': [(381L, u'ORG')],
#  u'16px 11px': [(388L, u'DATE')],
#  u'block;height:16px;width:16px}#chm': [(378L, u'PERSON')],
#  u'block;height:29px;line': [(378L, u'PERSON')],
#  u'xmlns="http://www.w3.org/1999/xhtml': [(378L, u'PERSON')],
#  u'time</div><span': [(382L, u'GPE')],
#  u'221:case': [(394L, u'CARDINAL')],
#  u'c;a': [(9191306739292312949L, u'FAC')],
#  u'relative;top:10px;width:20px}.gb_6a.gb_5a&gt;button': [(378L, u'PERSON')],
#  u'd.call(e,c': [(381L, u'ORG')],
#  u'd){d?_.Q(a': [(394L, u'CARDINAL')],
#  u' ': [(379L, u'NORP')],
#  u'class="spch': [(379L, u'NORP')],
#  u'0.218s;visibility': [(394L, u'CARDINAL')],
#  u'none}.gb_Q': [(378L, u'PERSON')],
#  u'function(){An': [(382L, u'GPE')],
#  u'g=0;g&lt;Ic.length;g++)d': [(378L, u'PERSON')],
#  u'Re=_.Fe;_.k': [(378L, u'PERSON')],
#  u'none;color:#5e97f6}.gb_ld': [(394L, u'CARDINAL')],
#  u'a.substr(0,a.length-1));return': [(378L, u'PERSON')],
#  u'A.w(a': [(378L, u'PERSON')],
#  u'S(),"authuser",a': [(378L, u'PERSON')],
#  u'1px': [(393L, u'ORDINAL')],
#  u'd?a.setAttribute(e': [(379L, u'NORP')],
#  u'c={},d=0;d&lt;b.length;d+=2)c[b[d]]=JSON.parse(b[d+1]);a': [(379L,
#    u'NORP')],
#  u'function(a){_.ua.call(this);this.ka': [(381L, u'ORG')],
#  u'this.o));this.o.start': [(381L, u'ORG')],
#  u'null,1': [(382L, u'GPE')],
#  u'id="hdtb " role="navigation': [(386L, u'WORK_OF_ART')],
#  u'History\\u003C': [(382L, u'GPE')],
#  u'About Us</a': [(394L, u'CARDINAL')],
#  u'Array.prototype.map?function(a': [(379L, u'NORP')],
#  u'0)?_.nf(void': [(394L, u'CARDINAL')],
#  u'd,-3);break;case 39:e': [(381L, u'ORG')],
#  u'c){if(a.forEach&amp;&amp;"function"==typeof': [(381L, u'ORG')],
#  u'0;margin - left:-1px}.kbtn - small{min - width:26px;width:26px}.ksb{background': [(384L,
#    u'PRODUCT')],
#  u'\xa0': [(378L, u'PERSON'),
#   (378L, u'PERSON'),
#   (378L, u'PERSON'),
#   (381L, u'ORG'),
#   (378L, u'PERSON'),
#   (381L, u'ORG'),
#   (378L, u'PERSON'),
#   (378L, u'PERSON'),
#   (378L, u'PERSON')],
#  u'd[h],e': [(378L, u'PERSON')],
#  u'g=0;g&lt;c.length;g++)this.ra(a': [(378L, u'PERSON')],
#  u'Freshers &': [(381L, u'ORG')],
#  u'B.length;c++)this': [(381L, u'ORG')],
#  u'De.apply(null': [(381L, u'ORG')],
#  u'\n Md': [(385L, u'EVENT')],
#  u'2767': [(388L, u'DATE')],
#  u'Nn);_.k=_.On.prototype;_.k.ai=_.Ne': [(382L, u'GPE')],
#  u'K||this': [(378L, u'PERSON')],
#  u'64px);margin - top:10px;top:2px;opacity:0;transition': [(394L,
#    u'CARDINAL')],
#  u'B+a': [(378L, u'PERSON')],
#  u'g||null': [(382L, u'GPE')],
#  u'd;this.o': [(378L, u'PERSON')],
#  u'0;opacity:.54}.gb_Af{display': [(394L, u'CARDINAL')],
#  u'null,0,0,null': [(393L, u'ORDINAL')],
#  u'dcdcdc;color:#555}.kpgrb': [(391L, u'MONEY')],
#  u'0 7px;position': [(394L, u'CARDINAL')],
#  u'id="eobp_1"': [(382L, u'GPE')],
#  u'cp.l cp.me': [(378L, u'PERSON')],
#  u'e),l=0&lt;d?1:-1;e&amp;&amp;0!=d;){do': [(381L, u'ORG')],
#  u'marginheight="3 " topmargin="3': [(386L, u'WORK_OF_ART')],
#  u'# 4d90fe;box': [(391L, u'MONEY')],
#  u'6': [(394L, u'CARDINAL')],
#  u'26px 22px': [(388L, u'DATE')],
#  u'0s;transition': [(394L, u'CARDINAL')],
#  u'# gbqf{max - width:572px;min - width:572px}.gbqfh': [(391L, u'MONEY')],
#  u'0px}#botabar{-webkit': [(394L, u'CARDINAL')],
#  u'Si': [(378L, u'PERSON')],
#  u'Sc': [(378L, u'PERSON')],
#  u'Se': [(378L, u'PERSON')],
#  u'id\\x3d\\x22li_1\\x22\\x3e\\x3ca': [(381L, u'ORG')],
#  u'inline}#obsmtc a,.rscontainer': [(381L, u'ORG')],
#  u'this),0));_.x("gbar.elc",(0,_.v)(this .': [(389L, u'TIME')],
#  u'this)}};_.k.clone': [(394L, u'CARDINAL')],
#  u'ebebeb;margin:0;}._oDv,._pFv{margin': [(391L, u'MONEY')],
#  u'div.tsf-p,form&gt;div.tsf-p{margin:-1px 0': [(448L, u'LAW')],
#  u'a.offsetWidth': [(381L, u'ORG')],
#  u'se(/Firefox\\/([0': [(382L, u'GPE')],
#  u'100 %': [(390L, u'PERCENT')],
#  u'Jobs - Monster': [(378L, u'PERSON')],
#  u'La(Oa))}_.x("gbar.up.gpd",function(){return': [(378L, u'PERSON')],
#  u'0);hd': [(394L, u'CARDINAL')],
#  u'Google</span': [(382L, u'GPE')],
#  u'a||null)].join': [(378L, u'PERSON')],
#  u'c.join': [(378L, u'PERSON')],
#  u'2px 6px': [(388L, u'DATE')],
#  u'Explore < em': [(378L, u'PERSON')],
#  u'18px}</style><script': [(394L, u'CARDINAL')],
#  u'c;a:{if(a.w.length&amp;&amp;(c': [(382L, u'GPE')],
#  u'H.log(c': [(381L, u'ORG')],
#  u'd.o):k(a': [(394L, u'CARDINAL')],
#  u'b);a': [(381L, u'ORG')],
#  u'192:case': [(394L, u'CARDINAL')],
#  u'd\\x3d1/t\\x3dzcms': [(378L, u'PERSON')],
#  u'a);google.tick("load",g': [(378L, u'PERSON')],
#  u'a.length': [(378L, u'PERSON')],
#  u'0==f&amp;&amp;(f': [(394L, u'CARDINAL')],
#  u'baseline}a.ab_button': [(378L, u'PERSON')],
#  u'top}._rgd{color:#999}._Tib,._Tib': [(394L, u'CARDINAL')],
#  u'MIT': [(381L, u'ORG')],
#  u'24': [(394L, u'CARDINAL')],
#  u'Ho;Co': [(378L, u'PERSON')],
#  u'g);a': [(378L, u'PERSON')],
#  u'window.innerHeight||0,vw': [(394L, u'CARDINAL')],
#  u'block}.gbqfh': [(378L, u'PERSON')],
#  u'Module_:_r': [(378L, u'PERSON')],
#  u'rgba(0,0,0,0.2)}.ab_dropdown': [(382L, u'GPE')],
#  u'class="gb_aa"></div><span': [(382L, u'GPE')],
#  u'L': [(382L, u'GPE')],
#  u'Companies House': [(381L, u'ORG')],
#  u'Error("R`"+c);_.n(d)||(d=-1);f': [(381L, u'ORG')],
#  u'a.listener': [(379L, u'NORP')],
#  u'null)+Xf(e),void': [(381L, u'ORG')],
#  u'class="unknown_loc"></span><span': [(382L, u'GPE')],
#  u'null,1]\\n': [(382L, u'GPE')],
#  u'219:case': [(394L, u'CARDINAL')],
#  u'c.height': [(382L, u'GPE')],
#  u'32px': [(393L, u'ORDINAL')],
#  u'ba},H': [(381L, u'ORG')],
#  u'd3l': [(382L, u'GPE')],
#  u'null;_.Kj': [(379L, u'NORP')],
#  u'none}.ng{color:#dd4b39}h1,ol': [(378L, u'PERSON')],
#  u'-32px 26px': [(388L, u'DATE')],
#  u'radius:0;margin - left:-1px}.ksb.right{-webkit': [(378L, u'PERSON')],
#  u'16px}._OXf': [(394L, u'CARDINAL')],
#  u'absolute;right:0}.gb_Jf{background:#f1f1f1}.gb_Fg': [(379L, u'NORP')],
#  u'Reliance Infocomm Limited': [(381L, u'ORG')],
#  u'c)Object.prototype.hasOwnProperty.call(c': [(382L, u'GPE')],
#  u'Monsterindia.com': [(381L, u'ORG')],
#  u'un(a': [(382L, u'GPE')],
#  u'Gmail</span></a></li><li': [(382L, u'GPE')],
#  u'T[g];g++)d= \n': [(9191306739292312949L, u'FAC')],
#  u'K);this.qa=!1};_.k': [(394L, u'CARDINAL')],
#  u'T={}};_.Ud.prototype': [(381L, u'ORG')],
#  u'this.w(a': [(378L, u'PERSON')],
#  u'ved="0ahUKEwiXuf65ibnZAhUJUZQKHfTkD_0Q7B0IUjAF"><span': [(382L, u'GPE')],
#  u'Report': [(381L, u'ORG')],
#  u'id="sfdiv"><button class="sbico - c': [(378L, u'PERSON')],
#  u'4px': [(393L, u'ORDINAL')],
#  u'b){google.lq.push([a': [(381L, u'ORG')],
#  u'null);return': [(378L, u'PERSON')],
#  u'6b90da;background:#f0f7f9}#cnt{clear': [(391L, u'MONEY')],
#  u'style="margin': [(378L, u'PERSON')],
#  u'Ed': [(378L, u'PERSON')],
#  u'Ef': [(381L, u'ORG')],
#  u'AREA BUTTON HEAD INPUT': [(381L, u'ORG')],
#  u'a.right),h': [(394L, u'CARDINAL')],
#  u'Array.prototype.some.call(a': [(378L, u'PERSON')],
#  u'hover,.msel': [(381L, u'ORG')],
#  u'fff}a.gb_Ba{border': [(391L, u'MONEY')],
#  u'c){a.o||2!=a.b&amp;&amp;3!=a.b||ke(a);a': [(382L, u'GPE')],
#  u'Xa();if(_.p(a))return': [(378L, u'PERSON')],
#  u'e=0,f': [(379L, u'NORP')],
#  u'FRTb2aDIjnc': [(382L, u'GPE')],
#  u'11.99': [(394L, u'CARDINAL')],
#  u'Press Enter': [(381L, u'ORG')],
#  u'a=_.H(_.L(),_.rj,13)||new': [(381L, u'ORG')],
#  u'0.0s}.ab_button': [(394L, u'CARDINAL')],
#  u'code")?_.v': [(381L, u'ORG')],
#  u'Ca&amp;&amp;this.o&amp;&amp;_.Ge(this.o);this.w': [(381L, u'ORG')],
#  u'result_id",null': [(393L, u'ORDINAL')],
#  u'c+"Left");e=_.ef(a': [(381L, u'ORG')],
#  u'Google Search</title><script': [(386L, u'WORK_OF_ART')],
#  u'5.91': [(394L, u'CARDINAL')],
#  u'X&amp;ved=0ahUKEwiXuf65ibnZAhUJUZQKHfTkD_0Q_AUIECgB"': [(378L, u'PERSON')],
#  u'Xj': [(378L, u'PERSON')],
#  u'Xi': [(378L, u'PERSON')],
#  u'ab_button': [(388L, u'DATE')],
#  u'# d9d9d9;border': [(391L, u'MONEY')],
#  u'span,#rhs': [(378L, u'PERSON')],
#  u'Xd': [(378L, u'PERSON')],
#  u'h]);if(google.c.c.e||google.c.c.g)google.tick("webaft",[l': [(378L,
#    u'PERSON')],
#  u'11.99 5': [(384L, u'PRODUCT')],
#  u'a)?this.o[a]:c }': [(378L, u'PERSON')],
#  u'60&gt;d?(r': [(394L, u'CARDINAL')],
#  u'Reliance Communications': [(381L, u'ORG')],
#  u'c){return Array.prototype.indexOf.call(a': [(388L, u'DATE')],
#  u'a.vk_cf': [(382L, u'GPE')],
#  u'null;_.Do': [(382L, u'GPE')],
#  u'nonce="n3ogM0+lKgMSPvke40WPGg==">/': [(379L, u'NORP')],
#  u'4285f4;font': [(391L, u'MONEY')],
#  u'class="rc"><h3': [(379L, u'NORP')],
#  u'Nh[a];c||(c="\\\\u"+(a.charCodeAt(0)|65536).toString(16).substr(1),Nh[a]=c);return': [(378L,
#    u'PERSON')],
#  u'X&amp;&amp;this.ca&amp;&amp;_.Q(a.b': [(382L, u'GPE')],
#  u'search</a><a': [(382L, u'GPE')],
#  u'd[4]),_.qg(this': [(378L, u'PERSON')],
#  u'rgba(0,0,0,0.2);margin:0;min': [(382L, u'GPE')],
#  u'18px;text': [(394L, u'CARDINAL')],
#  u'Best Online Job Portal': [(381L, u'ORG')],
#  u'Google': [(384L, u'PRODUCT')],
#  u'c;c =': [(381L, u'ORG')],
#  u'W&amp;&amp;(_.M(a.b,"mousedown",a.uf,!1,a),this.fa&amp;&amp;_.Q(a.b': [(382L,
#    u'GPE')],
#  u'card_id': [(394L, u'CARDINAL')],
#  u'function(){throw': [(388L, u'DATE')],
#  u'0 8px}.gsst_a{width': [(394L, u'CARDINAL')],
#  u'X&amp;ved=0ahUKEwiXuf65ibnZAhUJUZQKHfTkD_0Q_AUIDCgD"': [(382L, u'GPE')],
#  u'Module_:sy8 * / \n': [(385L, u'EVENT')],
#  u'.rj': [(378L, u'PERSON')],
#  u'c)}):a.className=(0,_.xa)(sf(a),function(a){return!_.Dc(c': [(388L,
#    u'DATE')],
#  u'K=_.K(_.F(a,5),-1);this': [(394L, u'CARDINAL')],
#  u'LTD - Overview': [(381L, u'ORG')],
#  u'Jo': [(378L, u'PERSON')],
#  u'Ji': [(378L, u'PERSON')],
#  u'8': [(394L, u'CARDINAL')],
#  u'Ja': [(378L, u'PERSON')],
#  u'Jb': [(378L, u'PERSON')],
#  u'B&amp;&amp;4==(a.b?a.b.readyState:0))_.qe(a': [(378L, u'PERSON')],
#  u'snapshot.asp%3FprivcapId%3D7372777+&amp;cd=10&amp;hl': [(379L, u'NORP')],
#  u'd;(d=0&lt;=c)&amp;&amp;Array.prototype.splice.call(a': [(378L, u'PERSON')],
#  u'A&amp;&amp;(_.m.clearTimeout(a': [(394L, u'CARDINAL')],
#  u'A++);this.o[a]=c};_.k.forEach': [(379L, u'NORP')],
#  u'class="gstl_0': [(378L, u'PERSON')],
#  u'0==this.w': [(394L, u'CARDINAL')],
#  u'nowrap}#fsl{white': [(379L, u'NORP')],
#  u'a{color:#878787': [(382L, u'GPE')],
#  u'Xc': [(378L, u'PERSON')],
#  u'f;g': [(378L, u'PERSON')],
#  u'a.capture):c.detachEvent?c.detachEvent(Nd(d),e):c.addListener&amp;&amp;c.removeListener&amp;&amp;c.removeListener(e);Hd--;(d=_.Ld(c))?(Ed(d': [(382L,
#    u'GPE')],
#  u'X&amp;ved=0ahUKEwiXuf65ibnZAhUJUZQKHfTkD_0Q1QIIdCgD"': [(378L, u'PERSON')],
#  u'0.218s}._zpc{box': [(394L, u'CARDINAL')],
#  u'f){(f||this.b).w(a': [(378L, u'PERSON')],
#  u'jsl="$x 3': [(386L, u'WORK_OF_ART')],
#  u'jsl="$x 2': [(386L, u'WORK_OF_ART')],
#  u'#': [(394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (386L, u'WORK_OF_ART'),
#   (386L, u'WORK_OF_ART'),
#   (386L, u'WORK_OF_ART'),
#   (386L, u'WORK_OF_ART'),
#   (386L, u'WORK_OF_ART'),
#   (386L, u'WORK_OF_ART'),
#   (386L, u'WORK_OF_ART'),
#   (386L, u'WORK_OF_ART'),
#   (394L, u'CARDINAL'),
#   (386L, u'WORK_OF_ART'),
#   (386L, u'WORK_OF_ART')],
#  u'e)}catch(f){pe.call(null ,': [(388L, u'DATE')],
#  u'c,!1):a.attachEvent&amp;&amp;a.attachEvent("on"+b': [(379L, u'NORP')],
#  u'id="rcnt': [(394L, u'CARDINAL')],
#  u'2px;visibility': [(394L, u'CARDINAL')],
#  u'0==d.returnValue)d.returnValue=!0}d=[];for(f': [(394L, u'CARDINAL')],
#  u'again\\u003C / span\\u003E","nv":"Please': [(384L, u'PRODUCT')],
#  u'10px}.gb_sb': [(394L, u'CARDINAL')],
#  u'c="': [(382L, u'GPE')],
#  u'annual': [(388L, u'DATE')],
#  u'none;vertical': [(394L, u'CARDINAL')],
#  u'this.right+=Number(c),this.bottom+=Number(d),this.left-=Number(e));return': [(378L,
#    u'PERSON')],
#  u'.Id(a': [(384L, u'PRODUCT')],
#  u'a.flt': [(378L, u'PERSON')],
#  u'function(){this.ga': [(394L, u'CARDINAL')],
#  u'J.log.call(this': [(381L, u'ORG')],
#  u'4': [(394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL'),
#   (394L, u'CARDINAL')],
#  u'subsidiaries</div></div><span': [(382L, u'GPE')],
#  u'Nb?a': [(381L, u'ORG')],
#  u'pp,1));_.x("gbar.ach",(0,_.v)(pp.tc': [(378L, u'PERSON')],
#  u'0,c': [(384L, u'PRODUCT')],
#  u'hasOwnProperty': [(388L, u'DATE')],
#  u'16px': [(393L, u'ORDINAL')],
#  u'Jobs | LinkedIn</a></h3><div class="s"><div><div': [(381L, u'ORG')],
#  u'd[f],g': [(379L, u'NORP')],
#  u'd(a': [(381L, u'ORG')],
#  u'href="//support.google.com / websearch/?p = ws_results_help&amp;hl = en': [(386L,
#    u'WORK_OF_ART')],
#  u'scale(1,1);-webkit': [(378L, u'PERSON')],
#  u'A.B(a': [(378L, u'PERSON')],
#  u'c}if(Hb&amp;&amp;a': [(393L, u'ORDINAL')],
#  u'27:return!(_.eb||_.bb)}return': [(381L, u'ORG')],
#  u'c0c0c0;box': [(391L, u'MONEY')],
#  u'right:4px;margin - top:14px}.tbos,.tbots,.tbotu{color:#dd4b39}.tbou&gt;a.q,#tbpi,#tbtro,.tbt': [(384L,
#    u'PRODUCT')],
#  u'c6c6c6;color:#222;}#hdtb': [(391L, u'MONEY')],
#  u'9': [(394L, u'CARDINAL')],
#  u'a.join': [(382L, u'GPE')],
#  u'class="spcht': [(382L, u'GPE')],
#  u'class="_wPb"><span class="_AUb"></span><div': [(382L, u'GPE')],
#  u'c"><li': [(382L, u'GPE')],
#  u'd.call(a,b)}},B=function(a){a=a.target||a.srcElement;!a.getAttribute&amp;&amp;a.parentNode&amp;&amp;(a=a.parentNode);return': [(378L,
#    u'PERSON')],
#  u'f=!1;"mouseenter"==c?c="mouseover":"mouseleave"==c&amp;&amp;(c="mouseout");if(b.addEventListener){if("focus"==c||"blur"==c||"error"==c||"load"==c)f=!0;b.addEventListener(c': [(382L,
#    u'GPE')],
#  u'Limited': [(381L, u'ORG')],
#  u'none;background:#fff;padding:0': [(381L, u'ORG')],
#  u'Private Company Information - Bloomberg</a></h3><div': [(381L, u'ORG')],
#  u'a;f': [(382L, u'GPE')],
#  u'hidden;padding:0}#ab_ctls': [(394L, u'CARDINAL')],
#  u'function(){return!Pi()&amp;&amp;(_.A("iPod")||_.A("iPhone")||_.A("Android")||_.A("IEMobile"))};Ri': [(378L,
#    u'PERSON')],
#  u'se(/Version\\/([0': [(381L, u'ORG')],
#  u'id="sifm"></span': [(382L, u'GPE')],
#  u'this.o);return': [(378L, u'PERSON')],
#  u'rgba(0,0,0,0.2);box - sizing': [(385L, u'EVENT')],
#  u'q);h=!0;break': [(391L, u'MONEY')],
#  u'Navi Mumbai - Service': [(378L, u'PERSON')],
#  u'Mobiles': [(384L, u'PRODUCT')],
#  u'Window.prototype&amp;&amp;!_.A("Edge")&amp;&amp;_.m': [(382L, u'GPE')],
#  u'Math.random();while(google.y[c])}google.y[c]=[a': [(382L, u'GPE')],
#  u'\n Go': [(385L, u'EVENT')],
#  u'B.push([c': [(382L, u'GPE')],
#  u'up.r up.sl': [(381L, u'ORG')],
#  u'Od': [(378L, u'PERSON')],
#  u'Oc': [(448L, u'LAW')],
#  u'e.target': [(388L, u'DATE')],
#  u'class="gb_Nc"><a class="gb_b gb_dc': [(381L, u'ORG')],
#  u'translateZ(0)}.gb_Ab{-webkit': [(393L, u'ORDINAL')],
#  u'rhs{margin - left:820px}.mw': [(381L, u'ORG')],
#  u'T.hasOwnProperty(d)&amp;&amp;_.Qd(a)},a);a': [(394L, u'CARDINAL')],
#  ...}

# %%
entities(example,True)

# %%
example
# Out:
# u"That this House notes the announcement of 300 redundancies at the Nestl\xe9 manufacturing factories in York, Fawdon, Halifax and Girvan and that production of the Blue Riband bar will be transferred to Poland; acknowledges in the first three months of 2017 Nestl\xe9 achieved \xa321 billion in sales, a 0.4 per cent increase over the same period in 2016; further notes 156 of these job losses will be in York, a city that in the last six months has seen 2,000 job losses announced and has become the most inequitable city outside of the South East, and a further 110 jobs from Fawdon, Newcastle; recognises the losses come within a month of triggering Article 50, and as negotiations with the EU on the UK leaving the EU and the UK's future with the EU are commencing; further recognises the cost of importing products, including sugar, cocoa and production machinery, has risen due to the weakness of the pound and the uncertainty over the UK's future relationship with the single market and customs union; and calls on the Government to intervene and work with hon. Members, trades unions GMB and Unite and the company to avert these job losses now and prevent further job losses across Nestle"

# %%
from selenium import webdriver
url = "https://www.google.com.tr/search?q={}".format("ril infotech")   
browser = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver")
browser.get(url)
browser.save_screenshot('screenie.png')
browser.quit()
# Out:
# -----------------------------------------------------------------------
# NoSuchWindowException                 Traceback (most recent call last)
# <ipython-input-83-88ff4b69ca60> in <module>()
#       3 browser = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver")
#       4 browser.get(url)
# ----> 5 browser.save_screenshot('screenie.png')
#       6 browser.quit()
#
# /home/nitin/anaconda2/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in save_screenshot(self, filename)
#    1029             driver.save_screenshot('/Screenshots/foo.png')
#    1030         """
# -> 1031         return self.get_screenshot_as_file(filename)
#    1032
#    1033     def get_screenshot_as_png(self):
#
# /home/nitin/anaconda2/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in get_screenshot_as_file(self, filename)
#    1006             warnings.warn("name used for saved screenshot does not match file "
#    1007                           "type. It should end with a `.png` extension", UserWarning)
# -> 1008         png = self.get_screenshot_as_png()
#    1009         try:
#    1010             with open(filename, 'wb') as f:
#
# /home/nitin/anaconda2/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in get_screenshot_as_png(self)
#    1038             driver.get_screenshot_as_png()
#    1039         """
# -> 1040         return base64.b64decode(self.get_screenshot_as_base64().encode('ascii'))
#    1041
#    1042     def get_screenshot_as_base64(self):
#
# /home/nitin/anaconda2/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in get_screenshot_as_base64(self)
#    1048             driver.get_screenshot_as_base64()
#    1049         """
# -> 1050         return self.execute(Command.SCREENSHOT)['value']
#    1051
#    1052     def set_window_size(self, width, height, windowHandle='current'):
#
# /home/nitin/anaconda2/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in execute(self, driver_command, params)
#     310         response = self.command_executor.execute(driver_command, params)
#     311         if response:
# --> 312             self.error_handler.check_response(response)
#     313             response['value'] = self._unwrap_value(
#     314                 response.get('value', None))
#
# /home/nitin/anaconda2/lib/python2.7/site-packages/selenium/webdriver/remote/errorhandler.pyc in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=64.0.3282.167)
#   (Driver info: chromedriver=2.33 (0),platform=Linux 4.13.0-32-generic x86_64)

# %%
from PIL import Image, ImageEnhance, ImageFilter
import pytesseract
#path = 'temp.png'
#img = Image.open(path)
#img = img.convert('RGBA')
#pix = img.load()
#for y in range(img.size[1]):
#    for x in range(img.size[0]):
#        if pix[x, y][0] < 102 or pix[x, y][1] < 102 or pix[x, y][2] < 102:
#            pix[x, y] = (0, 0, 0, 255)
#        else:
#            pix[x, y] = (255, 255, 255, 255)
#img.save('temp.jpg')
text = pytesseract.image_to_string(Image.open('temp.png'))
# os.remove('temp.jpg')
print(text)

# %%
text
# Out:
# u'@OU\xa9EEB relianoeinfntenn \xa2 (1\n\n \n\n \n\nAll News Maps Images waeas Mme Semngs Tools\n\n \n\nAboul 5.4mm resulls (0 32 seconds)\n\nWorking at Reliance lnfoTech | Glassdoor.co.in\nMpg:Ilwvmglam\ufb01mmo.iil..JWorkiwst-Weliam\xbblmnTedrELlETHEW.\u201c28111 v\nWt Ranng 4 , 1 review\n\nJan 17,2n14 , see man employees say abnul what we ike in work at Relhm Imo\'lbcn Salanesv\nrevlevls am more 73" med by enpiayees mung alRellance lnloTbch\n\nReliance infotech Jobs - Monster India\n\nmms\ufb01erimia.mnvreliam\xbbimoledrjobs.vml v\nApplym2767 Reliance Immch Jonson MnnsTennmanzm, lmla\u2018s Besl Onllne Jen Pnnal Find Law\nReliance Immch Jon vammes for Freshers a. Expevemzsd amass Top Canpanles\n\nReliance Global Services , IT Services and Solulions\n\nmmisnmglobalmw v\n\nReliance thal Servmes Pvn m Is one mmefasl gmng l\'l\u2019sollmons and servlces pmvmervnlh\nWm m usA Hyderabad-In\ufb01ll delivering nesrmuss sewms in help clams reduce mas, enname\nmganlzalhnal mainly and mpme business and n pemxmance We have pmven capahinles across\nnnnus lnnus1ry ,,\n\nAhanl Us Pm\ufb01ler n emsunmg Rel Track\n\nReliance lnlotech, Navi Mumbai - Service Provider of Cuslomer\nImps Iww mimennm/oompmylmeaazal v\n\n4\u2014 >'

# %%
from pws import Google
from pws import Bing
a =Google.search(query='infoedge', num=5, start=0, country_code="in")
a
# Out:
# {'country_code': 'in',
#  'expected_num': 5,
#  'received_num': 0,
#  'related_queries': ['info edge wiki',
#   'info edge india subsidiaries',
#   'info edge glassdoor',
#   'info edge india ltd salary',
#   'info edge india ltd share price',
#   'info edge india ltd noida sector 2',
#   'info edge careers',
#   'info edge recruitment process'],
#  'results': [],
#  'search_engine': 'google',
#  'start': 0,
#  'total_results': 4870000,
#  'url': 'https://www.google.com/search?q=infoedge&num=5&start=0&gl=in'}

# %%
#coding=utf-8

from bs4 import BeautifulSoup
from time import sleep as wait
import re
import requests

try:
    from html.parser import HTMLParser
except ImportError:
    from HTMLParser import HTMLParser

##################################################
# Copied code
##################################################

class MLStripper(HTMLParser):
    # Code copied from StackOverflow http://stackoverflow.com/a/925630/3664835
    def __init__(self):
        self.reset()
        self.strict = False
        self.convert_charrefs= True
        self.fed = []
    def handle_data(self, d):
        self.fed.append(d)
    def get_data(self):
        return ''.join(self.fed)

def strip_tags(html):
    # Code copied from StackOverflow http://stackoverflow.com/a/925630/3664835
    s = MLStripper()
    s.feed(html)
    return ' '.join(s.get_data().split())

##################################################
# Helpers
##################################################

# https://www.google.com/search?q=hello+world&num=3&start=0
def generate_url(query, num, start, recent, country_code):
    """(str, str, str) -> str
    A url in the required format is generated.
    """
    query = '+'.join(query.split())
    url = 'https://www.google.com/search?q=' + query + '&num=' + num + '&start=' + start
    if recent in ['h', 'd', 'w', 'm', 'y']:
        url += '&tbs=qdr:' + recent
    if country_code is not None:
        url += '&gl=' + country_code
    return url

# Sortbydate: tbs=sbd:1
# Best:      https://www.google.co.in/search?q=hello+world&tbm=nws#q=hello+world&tbas=0&tbm=nws
# 1 hour:    &tbs=qdr:h
# 1 day:     &tbs=qdr:d
# 1 week:    &tbs=qdr:w
# 1 month:   &tbs=qdr:m
# 1 year:    &tbs=qdr:y
def generate_news_url(query, num, start, recent, country_code):
    query = '+'.join(query.split())
    url = 'https://www.google.com/search?q=' + query + '&num=' + num + '&start=' + start
    url += '&tbm=nws#q=' + query + '&tbas=0&tbs=sbd:1&tbm=nws'
    if recent in ['h', 'd', 'w', 'm', 'y']:
        url += '&tbs=qdr:' + recent
    if country_code is not None:
        url += '&gl=' + country_code
    return url

def try_cast_int(s):
    """(str) -> int
    All the digits in a given string are concatenated and converted into a single number.
    """
    try:
        temp = re.findall('\d', str(s))
        temp = ''.join(temp)
        return int(temp)
    except:
        return s

##################################################
# Class
##################################################


class Google:
    @staticmethod
    def search(query, num=10, start=0, sleep=True, recent=None, country_code=None):
        if sleep:
            wait(1)
        url = generate_url(query, str(num), str(start), recent, country_code)
        soup = BeautifulSoup(requests.get(url).text, "html.parser")
        results = Google.scrape_search_result(soup)
        related_queries = Google.scrape_related(soup)

        raw_total_results = soup.find('div', attrs = {'class' : 'sd'}).string
        total_results = 0
        if raw_total_results is not None:
            for i in raw_total_results:
                try:
                    temp = int(i)
                    total_results = total_results * 10 + temp
                except:
                    continue

        temp = {'results' : results,
                'url' : url,
                'expected_num' : num,
                'received_num' : len(results),
                'start' : start,
                'search_engine': 'google',
                'related_queries' : related_queries,
                'total_results' : total_results,
                'country_code': country_code,
        }
        return temp

    @staticmethod
    def scrape_search_result(soup):
        raw_results = soup.find_all('div', attrs = {'class' : 'g'})
        results = []
        
        for result in raw_results:
            link = result.find('a').get('href')[7:]

            raw_link_text = result.find('a')
            link_text = strip_tags(str(raw_link_text))
            
            raw_link_info = result.find('span', attrs = {'class' : 'st'})
            link_info = strip_tags(str(raw_link_info))

            additional_links = dict()
            raw_additional_links = result.find('div', attrs = {'class' : 'osl'})
            if raw_additional_links is not None:
                for temp in raw_additional_links.find_all('a'):
                    additional_links[strip_tags(str(temp))] = temp.get('href')[7:]

            temp = { 'link' : link,
                     'link_text' : link_text,
                     'link_info' : link_info,
                     'additional_links' : additional_links,
            }

            results.append(temp)
        return results

    @staticmethod
    def scrape_related(soup):
        related_queries = []
        raw_related = soup.find_all('p', attrs = {'class' : '_Bmc'})
        for related in raw_related:
            related_queries.append(strip_tags(str(related.find('a'))))
        return related_queries

    @staticmethod
    def search_news(query, num=10, start=0,sleep=True, recent=None, country_code=None, proxies=None):
        if sleep:
            wait(1)
        url = generate_news_url(query, str(num), str(start), recent, country_code)
        soup = BeautifulSoup(requests.get(url,proxies).text, "html.parser")
        results = Google.scrape_news_result(soup)

        raw_total_results = soup.find('div', attrs = {'class' : 'sd'}).string
        total_results = 0
        for i in raw_total_results:
            try:
                temp = int(i)
                total_results = total_results * 10 + temp
            except:
                continue

        temp = {'results' : results,
                'url' : url,
                'num' : num,
                'start' : start,
                'search_engine' : 'google',
                'total_results' : total_results,
                'country_code': country_code,
        }
        return temp

    @staticmethod
    def scrape_news_result(soup):
        raw_results = soup.find_all('div', attrs = {'class' : 'g'})
        results = []

        for result in raw_results:
            link = result.find('a').get('href')[7:]

            raw_link_text = result.find('a')
            link_text = strip_tags(str(raw_link_text))

            raw_link_info = result.find('div', attrs = {'class' : 'st'})
            link_info = strip_tags(str(raw_link_info))

            raw_source = result.find('span', attrs = {'class' : 'f'})
            raw_source = strip_tags(str(raw_source)).split(' - ')

            source = raw_source[0]
            time = raw_source[1]

            additional_links = dict()

            # Crazy hack! Fix it. + Buggy!
            try:
                raw_a_links = result.find_all('a')[1:]
                if raw_a_links:
                    raw_source = list(map(strip_tags, list(map(str, result.find_all('span', attrs = {'class' : 'f'})[1:]))))
                    for idx in range(len(raw_a_links)-1):
                        additional_links[strip_tags(str(raw_a_links[idx]))] = (raw_a_links[idx].get('href'), raw_source[idx])
            except:
                pass

            temp = { 'link' : link,
                     'link_text' : link_text,
                     'link_info' : link_info,
                     'additional_links' : additional_links,
                     'source' : source,
                     'time' : time,
            }
            results.append(temp)
        return results

# %%
def scrape_search_result(soup):
    raw_results = soup.find_all('div', attrs = {'class' : 'g'})
    results = []

    for result in raw_results:
        link = result.find('a').get('href')[7:]

        raw_link_text = result.find('a')
        link_text = strip_tags(str(raw_link_text))

        raw_link_info = result.find('span', attrs = {'class' : 'st'})
        link_info = strip_tags(str(raw_link_info))

        additional_links = dict()
        raw_additional_links = result.find('div', attrs = {'class' : 'osl'})
        if raw_additional_links is not None:
            for temp in raw_additional_links.find_all('a'):
                additional_links[strip_tags(str(temp))] = temp.get('href')[7:]

        temp = { 
                 'link_text' : link_text,
                 'link_info' : link_info,
        }

        results.append(temp)
    return results

def scrape_related(soup):
    related_queries = []
    raw_related = soup.find_all('p', attrs = {'class' : '_Bmc'})
    for related in raw_related:
        related_queries.append(strip_tags(str(related.find('a'))))
    return related_queries

# %%
def search(query, num=10, start=0, sleep=True, recent=None, country_code=None):
        if sleep:
            wait(1)
        url = generate_url(query, str(num), str(start), recent, country_code)
        soup = BeautifulSoup(requests.get(url).text, "html.parser")
        results = Google.scrape_search_result(soup)
        related_queries = Google.scrape_related(soup)

        raw_total_results = soup.find('div', attrs = {'class' : 'sd'}).string
        total_results = 0
        if raw_total_results is not None:
            for i in raw_total_results:
                try:
                    temp = int(i)
                    total_results = total_results * 10 + temp
                except:
                    continue

        temp = {'results' : results,
                'url' : url,
                'expected_num' : num,
                'received_num' : len(results),
                'start' : start,
                'search_engine': 'google',
                'related_queries' : related_queries,
                'total_results' : total_results,
                'country_code': country_code,
        }
        return temp

# %%
a =search(query='wipro', num=5, start=0, country_code="in")
a
# Out:
# {'country_code': 'in',
#  'expected_num': 5,
#  'received_num': 5,
#  'related_queries': ['wipro india',
#   'wipro recruitment',
#   'wipro full form',
#   'wipro wiki',
#   'wipro subsidiaries',
#   'wipro bangalore',
#   'wipro products',
#   'nse:wipro'],
#  'results': [{'additional_links': {},
#    'link': u'https://www.wipro.com/en-IN/&sa=U&ved=0ahUKEwj1ycnjsrnZAhWhgVQKHX5iBjcQFggUMAA&usg=AOvVaw2K3vAymaoZs4dbOm8CxM2Z',
#    'link_info': 'Wipro delivers IT Services, Business and Technology Consulting, IT Outsourcing and System Integration services solutions.',
#    'link_text': 'IT Services, Consulting, System Integration IT Outsourcing - Wipro'},
#   {'additional_links': {},
#    'link': u'/maps.google.co.in/maps?num=5&gws_rd=cr&dcr=0&um=1&ie=UTF-8&fb=1&gl=in&sa=X&sll=28.566051,77.34427&sspn=0.1157938,0.1757994&q=wipro&ved=0ahUKEwj1ycnjsrnZAhWhgVQKHX5iBjcQtgMIIg',
#    'link_info': 'None',
#    'link_text': ''},
#   {'additional_links': {'Abidali Neemuchwala': u'https://en.wikipedia.org/wiki/Abidali_Neemuchwala&sa=U&ved=0ahUKEwj1ycnjsrnZAhWhgVQKHX5iBjcQ0gIIQCgBMAc&usg=AOvVaw0pDOxqUc3ROlBlvVrlgXN7',
#     'Amalner': u'https://en.wikipedia.org/wiki/Amalner&sa=U&ved=0ahUKEwj1ycnjsrnZAhWhgVQKHX5iBjcQ0gIIQigDMAc&usg=AOvVaw2ohDL6ZJFSI5DJ3yI5_nPs',
#     'Azim Premji': u'https://en.wikipedia.org/wiki/Azim_Premji&sa=U&ved=0ahUKEwj1ycnjsrnZAhWhgVQKHX5iBjcQ0gIIPygAMAc&usg=AOvVaw1jK9m6rT5uagd5xNZssHiG',
#     'List of Indian FMCG companies': u'https://en.wikipedia.org/wiki/List_of_Indian_FMCG_companies&sa=U&ved=0ahUKEwj1ycnjsrnZAhWhgVQKHX5iBjcQ0gIIQSgCMAc&usg=AOvVaw0kvVjTOvzwgAvNvvxVSYk9'},
#    'link': u'https://en.wikipedia.org/wiki/Wipro&sa=U&ved=0ahUKEwj1ycnjsrnZAhWhgVQKHX5iBjcQFgg5MAc&usg=AOvVaw11C5gdkmqxzlCoB7mcBv1H',
#    'link_info': 'Wipro Limited is an Indian Information Technology Services corporation headquartered in Bengaluru, India. In 2013, Wipro demerged its non-IT businesses into separate companies to bring in more focus on independent businesses. Contents. [hide]. 1 History. 1.1 Early formative years; 1.2 1966\xe2\x80\x931992; 1.3 1994\xe2\x80\x932000; 1.4\xc2\xa0...',
#    'link_text': 'Wipro - Wikipedia'},
#   {'additional_links': {},
#    'link': u'?q=wipro&num=5&dcr=0&ie=UTF-8&prmd=ivns&source=univ&tbm=nws&tbo=u&sa=X&ved=0ahUKEwj1ycnjsrnZAhWhgVQKHX5iBjcQqAIIRA',
#    'link_info': 'Speaking on the sidelines of World Congress on Information Technology in Hyderabad, Telangana minister for IT K. T. Rama Rao said, \xe2\x80\x9cWipro has a good presence in the state and its new manufacturing unit will boost the progress of the industrial sector in Telangana\xe2\x80\x9d. The minister also invited Wipro to\xc2\xa0...',
#    'link_text': 'News for wipro'},
#   {'additional_links': {},
#    'link': u'https://www.wipro.com/brand/&sa=U&ved=0ahUKEwj1ycnjsrnZAhWhgVQKHX5iBjcQndQBCF8wCw&usg=AOvVaw10H0cATo6rGzeWGTlAUExR',
#    'link_info': 'None',
#    'link_text': ''}],
#  'search_engine': 'google',
#  'start': 0,
#  'total_results': 4680000,
#  'url': 'https://www.google.com/search?q=wipro&num=5&start=0&gl=in'}
